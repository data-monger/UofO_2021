# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

import requests as req
from pprint import pprint as p

# Import API key
from config import g_api_key

# Configure gmaps API key
gmaps.configure(api_key=g_api_key)

# Base URL
url_1 = 'https://www.google.com/maps/dir/?api=' + g_api_key
url_2 = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json'

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("Resources/WeatherPy_database.csv")

# Check imported data set
city_data_df.head()
print(len(city_data_df.index))
# Out:
# 696

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
min_temp = input("Minimum Temperatur: ")
max_temp = input("Maximum Temperatur: ")

# %%
# convert to integer
min_temp = int(min_temp)
max_temp = int(max_temp)

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
filtered_city_data_df = city_data_df.loc[(city_data_df['Max Temp'] >= min_temp) & (city_data_df['Max Temp'] <= max_temp)]
#filtered_city_data_df = city_data_df.loc[(city_data_df['Max Temp'] <= max_temp) & (city_data_df['Max Temp'] >= min_temp)]

filtered_city_data_df
print(len(filtered_city_data_df.index))
# Out:
# 406

# %%
# 4a. Determine if there are any empty rows.
filtered_city_data_df.count()
# Out:
# City_ID                406
# City                   406
# Lat                    406
# Lng                    406
# Max Temp               406
# Current Description    406
# Rain (inches)          406
# Snow (inches)          406
# Humidity               406
# Cloudiness             406
# Wind Speed             406
# Country                403
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
filtered_city_data_df = filtered_city_data_df.dropna()

# %%
print(len(filtered_city_data_df.index))
# Out:
# 403

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = []
hotel_df = filtered_city_data_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

x = [i for i in range(len(hotel_df.index))]

# 5b. Create a new column "Hotel Name"
hotel_df['Hotel Name'] = ""
hotel_df['index_'] = x

hotel_df = hotel_df.set_index('index_')
hotel_df
# Out:
#                 City Country  Max Temp Current Description      Lat       Lng  \
# index_
# 0           Belmonte      BR     77.50       moderate rain -15.8631  -38.8828
# 1       Saint George      US     50.47           clear sky  37.1041 -113.5841
# 2             Avarua      CK     75.25    scattered clouds -21.2078 -159.7750
# 3          Kathmandu      NP     46.62          few clouds  27.7167   85.3167
# 4          Busselton      AU     72.09           clear sky -33.6500  115.3333
# ...              ...     ...       ...                 ...      ...       ...
# 398       Hervey Bay      AU     76.01          few clouds -25.2986  152.8535
# 399              Ati      TD     81.73    scattered clouds  13.2154   18.3353
# 400           Mumbwa      ZM     69.28       moderate rain -14.9783   27.0619
# 401          Vaitape      PF     80.04          few clouds -16.5167 -151.7500
# 402        Boyolangu      ID     76.33     overcast clouds  -8.1181  111.8935
#
#        Hotel Name
# index_
# 0
# 1
# 2
# 3
# 4
# ...           ...
# 398
# 399
# 400
# 401
# 402
#
# [403 rows x 7 columns]

# %%
print(len(filtered_city_data_df.index))
# Out:
# 403

# %%
#df.loc[(df['Salary_in_1000']>=100) & (df['Age']< 60) & (df['FT_Team'].str.startswith('S')),['Name','FT_Team']]
lat__ = hotel_df['Lat']
lng__ = hotel_df['Lng']

#lat__.iloc[0]
#lng__.iloc[0]
#
#print (lat__)
#print (lng__)

# %%
# 6a. Set parameters to search for hotels within 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_api_key
}


# 6b. Iterate through the hotel DataFrame.
for i, city in enumerate(hotel_df):
    # 6c. Get latitude and longitude from DataFrame
    lat_i = str(lat__.iloc[i]) 
    lng_i = str(lng__.iloc[i])


    # creating location key on 1st pass // replacing lat&long string on subsequent passes
    params["location"] = lat_i + ',' + lng_i
    
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    # this is above // url_2
    #print (params)
    
    # 6e. Make request and retrieve the JSON data from the search. 
    try:
        city_hotel = req.get(url_2, params = params).json()
        p(city_hotel)

    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
        #df.loc[(df['Salary_in_1000']>=100) & (df['Age']< 60) & (df['FT_Team'].str.startswith('S')),['Name','FT_Team']]    

        hotel_name = city_hotel['results'][0]['name']
        hotel_df.loc[i,'Hotel Name']= hotel_name 

        #hotel_df.loc[index, 'Hotel Name'] = city_hotel['results'][0]['name']

    except:
        print("Hotel not found in City. Skipping...")
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -15.8590807, 'lng': -38.8788983},
#                            'viewport': {'northeast': {'lat': -15.8577392197085,
#                                                       'lng': -38.87753036970851},
#                                         'southwest': {'lat': -15.8604371802915,
#                                                       'lng': -38.8802283302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Pousada Monte Carmelo O Pão',
#               'photos': [{'height': 2338,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/108836040145173663368">Maycon '
#                                                 'Borges</a>'],
#                           'photo_reference': 'Aap_uEDSk9OZ4Y1WwrKdLbgyrP58u1y_sLr2ZMkcystYosHgnjTrqiF9Id3BtUtDpIv-UIcbk00gHFe7X07NcC8NM4uGcMLYFGppM5gRAXniuGEtCSZGv6sRyYsK3E2WDY7iQwsXo9nX3qjz28kK57Cvz_Xds4IHgC94_TSWTz2w8g02ZLLI',
#                           'width': 2340}],
#               'place_id': 'ChIJ1ebL2947NwcR7TExb-U_uZE',
#               'plus_code': {'compound_code': '44RC+9C Belmonte, BA, Brazil',
#                             'global_code': '59P344RC+9C'},
#               'rating': 3.8,
#               'reference': 'ChIJ1ebL2947NwcR7TExb-U_uZE',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 13,
#               'vicinity': 'Avenida 23 de Maio, 394, Belmonte'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -15.856964, 'lng': -38.8816326},
#                            'viewport': {'northeast': {'lat': -15.8556062197085,
#                                                       'lng': -38.8803063197085},
#                                         'southwest': {'lat': -15.8583041802915,
#                                                       'lng': -38.8830042802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Pousada Rio',
#               'photos': [{'height': 480,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/106188177390285629338">Pousada '
#                                                 'Rio</a>'],
#                           'photo_reference': 'Aap_uEBOkk6I7j_7Cphuqdn751FvMarxPyIDBiAHc5xPxyA3RIhj7D9uNOm7Iq7Brh_iggmSrR__-Z3gI4boWmhd6QcLW8fs8rToGnZ63kTJeX8hR05-t68xWmP-XvsCUmJ8y2ITc4M53VzGk6vb3QW5FLNZW7Sl2GH7QsIXgu3zaSunIbhw',
#                           'width': 640}],
#               'place_id': 'ChIJ1w7kbuQ7NwcRrn1CQxot78g',
#               'plus_code': {'compound_code': '44V9+68 Belmonte, BA, Brazil',
#                             'global_code': '59P344V9+68'},
#               'rating': 4.2,
#               'reference': 'ChIJ1w7kbuQ7NwcRrn1CQxot78g',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 93,
#               'vicinity': 'Avenida Presidente Getúlio Vargas, 127, Belmonte'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -15.8627138,
#                                         'lng': -38.88227020000001},
#                            'viewport': {'northeast': {'lat': -15.8613260697085,
#                                                       'lng': -38.8809026697085},
#                                         'southwest': {'lat': -15.8640240302915,
#                                                       'lng': -38.8836006302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Pousada Belmonte',
#               'photos': [{'height': 2160,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/108653364691020679576">Leandro '
#                                                 'Junio</a>'],
#                           'photo_reference': 'Aap_uEDqqDOTazeYJENTceVXDZgmeNjHzEbgu30CzI2dxGnul4NMU4TV1P1vR8p4TJkr9ZzyqFnR4gaXURIcMk7fFUB-pMsdZfK9LkhZ0WajZGTMrVGih6reCBYGWTQ1hyF2txaMvGVj04oSn9x7BeLfCdF-UPJgrpenK2Lqf9BvDvUPlp0A',
#                           'width': 3840}],
#               'place_id': 'ChIJ_9zEnt07NwcRfXZ_lC-NjEE',
#               'plus_code': {'compound_code': '44P9+W3 Belmonte, BA, Brazil',
#                             'global_code': '59P344P9+W3'},
#               'rating': 3.8,
#               'reference': 'ChIJ_9zEnt07NwcRfXZ_lC-NjEE',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 58,
#               'vicinity': '09 Praça Manoel Veloso, Travessa da Matriz, '
#                           'Belmonte'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -15.8638122, 'lng': -38.8790713},
#                            'viewport': {'northeast': {'lat': -15.8624600697085,
#                                                       'lng': -38.8777210197085},
#                                         'southwest': {'lat': -15.8651580302915,
#                                                       'lng': -38.88041898029149}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'bahiabosque',
#               'place_id': 'ChIJb-sYYlY7NwcR8_RDhSVTlgs',
#               'plus_code': {'compound_code': '44PC+F9 Belmonte, BA, Brazil',
#                             'global_code': '59P344PC+F9'},
#               'reference': 'ChIJb-sYYlY7NwcR8_RDhSVTlgs',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'vicinity': 'pça, Travessa da Matriz, Belmonte'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -15.8633112, 'lng': -38.8754943},
#                            'viewport': {'northeast': {'lat': -15.8619131697085,
#                                                       'lng': -38.8741214197085},
#                                         'southwest': {'lat': -15.8646111302915,
#                                                       'lng': -38.87681938029149}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Pousada do Diogo',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1080,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/101593395990746531934">Pousada '
#                                                 'do Diogo</a>'],
#                           'photo_reference': 'Aap_uEBdc16jmSvhC-VXm1XFkI7hvzHafZIAl8RWdz59AH6uHKZQdGDhWlE3GEeXopzvN4xqKDtwAAlbwyNoonxCRa4-bMKmlZ6H67m210mwlwb0YuHl6cBoV38mBKzpW_bMRSIEZ26zDVtnEH9__fokAJaM2gclFn33QFJII1wJN7iSZ3Bn',
#                           'width': 1920}],
#               'place_id': 'ChIJ4eGcEDI7NwcRYnRGIe8TXW4',
#               'plus_code': {'compound_code': '44PF+MR Belmonte, BA, Brazil',
#                             'global_code': '59P344PF+MR'},
#               'rating': 4.8,
#               'reference': 'ChIJ4eGcEDI7NwcRYnRGIe8TXW4',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 24,
#               'vicinity': 'Avenida Rio Mar, Nº 908-A - CENTRO, Belmonte'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -15.8566338, 'lng': -38.8797217},
#                            'viewport': {'northeast': {'lat': -15.8552652697085,
#                                                       'lng': -38.87842326970851},
#                                         'southwest': {'lat': -15.8579632302915,
#                                                       'lng': -38.8811212302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Pousada Caçari',
#               'photos': [{'height': 2952,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/110298067066468996670">Wagner '
#                                                 'Cavalcante</a>'],
#                           'photo_reference': 'Aap_uEBzAy4Q_EBipDcYNe7rKdrodddRCwAI0pPcQbrC6jN42rYE08J4H_gUF3rLCVsfPvrK8jbDRmeO053ZA9ayw9okyjcctevPwBpMdPIcR6sqAdb-r57jkhViCzuSl0Pq3Ua3ntuhl4ccvc7dPYUjtDZAt0aSgs-SYMzJRxjJo13-XiNM',
#                           'width': 5248}],
#               'place_id': 'ChIJMQQtZN87NwcReabXvsO04EI',
#               'plus_code': {'compound_code': '44VC+84 Belmonte, BA, Brazil',
#                             'global_code': '59P344VC+84'},
#               'rating': 3.8,
#               'reference': 'ChIJMQQtZN87NwcReabXvsO04EI',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 28,
#               'vicinity': 'Avenida Dom Pedro II, 301, Belmonte'}],
#  'status': 'OK'}
# {'html_attributions': [],
#  'next_page_token': 'Aap_uECWwcGYmyO8kJsZ2ziUw9hqyHEXc2SPU84dp2y7bk0uBW7AZWOMPzVRg08TEVflD_tfTU_Ku2N8ykxwkNUXtFXZ1CvKpvAdSsSrANppqUvspInhXLvu48Bpwtc7F2NqWibXm6THG_xW345mv9Al1XFrKr97Gc04j3E7X2MAWvgWepNF5pbqYddbvDgCnxbj_cJ3zke2PHxqBAfVRUKPfBt8P30YSSkPz3kp228CwEit_KpQIgunva2-32wnyY6T07Zbet1Y1gYqLbxRLKw5ISKRVJOI_GHCeCUYOM-0-dtSnVjDwrWhfB1CjN6FEWuMJR08Ga8mKrEa24-cZm3XZB1eTy8P1tLMfPaTm4rl2sATPOP8N4ZrYQaBRn51opXTwaPsyHPjyFjdoVwbifVZvXd5AjxQz92jLlEZqiXTjkoIK9hLHPJlcRIB',
#  'results': [{'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 37.0890245, 'lng': -113.5842669},
#                            'viewport': {'northeast': {'lat': 37.0901987302915,
#                                                       'lng': -113.5824545},
#                                         'southwest': {'lat': 37.08750076970851,
#                                                       'lng': -113.5864653}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Best Western Plus Abbey Inn',
#               'photos': [{'height': 2160,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/110580949539846287401">Best '
#                                                 'Western Plus Abbey Inn</a>'],
#                           'photo_reference': 'Aap_uECVeOShBptxgO6bic--WxFnu_fq_6bXE8DQYDGgKKhbtOXg69PHdHDE8nUSsLSY6gg91Tfrms24srxvjj_vqkimgedjSnYR2y6geo1C6K1jj5pvk9uWjn6LjIB4LIj7m4C2pF79stbNW3m-oljy9xtUVqNhZAYcqo7PcY2HIc4vVytH',
#                           'width': 3840}],
#               'place_id': 'ChIJ63qpeiVFyoAROMhlOvr3-kI',
#               'plus_code': {'compound_code': '3CQ8+J7 St. George, UT, USA',
#                             'global_code': '85983CQ8+J7'},
#               'rating': 4.6,
#               'reference': 'ChIJ63qpeiVFyoAROMhlOvr3-kI',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 2064,
#               'vicinity': '1129 South Bluff Street, St. George'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 37.10494730000001,
#                                         'lng': -113.5519754},
#                            'viewport': {'northeast': {'lat': 37.1062962302915,
#                                                       'lng': -113.5507443697085},
#                                         'southwest': {'lat': 37.10359826970851,
#                                                       'lng': -113.5534423302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Courtyard by Marriott St. George',
#               'photos': [{'height': 1366,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/104027238087521980388">Courtyard '
#                                                 'by Marriott St. George</a>'],
#                           'photo_reference': 'Aap_uED2vihmNuo-LpoE-9KA1rIi-tfqCY1Dm6wGPU71r9cEHlBvSrIompBQPYb7NXMWEhwLtaYrHZDDCSqMAfAaTHyKvtTUiCVWOFKnj0noRWvm_BODULnXq5nFOIDZYGToAsCkni-9FaOhfvOQBQrMT2_FZkR3CsE60akNMYUyZg8IDsvM',
#                           'width': 2048}],
#               'place_id': 'ChIJsT-AhyBbyoAR4FchUIkpP_U',
#               'plus_code': {'compound_code': '4C3X+X6 St. George, UT, USA',
#                             'global_code': '85984C3X+X6'},
#               'rating': 4.5,
#               'reference': 'ChIJsT-AhyBbyoAR4FchUIkpP_U',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 596,
#               'vicinity': '185 South 1470 East, St. George'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 37.084156, 'lng': -113.5848236},
#                            'viewport': {'northeast': {'lat': 37.0856871302915,
#                                                       'lng': -113.5833002197085},
#                                         'southwest': {'lat': 37.0829891697085,
#                                                       'lng': -113.5859981802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Desert Garden Inn, A Trademark Collection Hotel',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 533,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/112405161253476492917">Desert '
#                                                 'Garden Inn, A Trademark '
#                                                 'Collection Hotel</a>'],
#                           'photo_reference': 'Aap_uEA1xSKg3jfBF-tuZ3eleU7my7Oc8iu2aRtSb-dm7EwD9Um_o2vIEyJSONO-J9YiHTPZ9jT8zICXr7Q9hQ7P4eHRA3VyNntdGUUWqCs_3ehkbam9qBJP97zR4joiCGRu8VktNxS3w_C-eM2FtW48q9YA3IeTT3ci7jTbSjzQrFdKwij6',
#                           'width': 800}],
#               'place_id': 'ChIJ0RZQdzpFyoAREXQfkpI4-Nw',
#               'plus_code': {'compound_code': '3CM8+M3 St. George, UT, USA',
#                             'global_code': '85983CM8+M3'},
#               'rating': 4.1,
#               'reference': 'ChIJ0RZQdzpFyoAREXQfkpI4-Nw',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 699,
#               'vicinity': '1450 South Hilton Drive, St. George'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 37.1096381, 'lng': -113.5529941},
#                            'viewport': {'northeast': {'lat': 37.1109870802915,
#                                                       'lng': -113.5517667697085},
#                                         'southwest': {'lat': 37.10828911970851,
#                                                       'lng': -113.5544647302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Ramada by Wyndham St George',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 400,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/117826311652767945774">Ramada '
#                                                 'by Wyndham St George</a>'],
#                           'photo_reference': 'Aap_uECxZgqATARtgjSa6nNqcUW6z4ywwKK8FOfqcHIgDbWS8m_-YdTSZBFPIV922Wxd1R19n9Nvg0ZQJ-laP-p90SukoVSZ0I80AVq5nxv1JQYZRBnr2xsIf5M3Yi66VU-Vuhql8JwK9OrNENfpjC-9lUbezKfYX1qw4ZrwHBfF94L3rmG9',
#                           'width': 600}],
#               'place_id': 'ChIJVbiA2SNbyoARPugMqQWYrGU',
#               'plus_code': {'compound_code': '4C5W+VR St. George, UT, USA',
#                             'global_code': '85984C5W+VR'},
#               'rating': 4.1,
#               'reference': 'ChIJVbiA2SNbyoARPugMqQWYrGU',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 864,
#               'vicinity': '1440 East Saint George Boulevard, St. George'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 37.0784851, 'lng': -113.5825771},
#                            'viewport': {'northeast': {'lat': 37.0798233802915,
#                                                       'lng': -113.5813407197085},
#                                         'southwest': {'lat': 37.0771254197085,
#                                                       'lng': -113.5840386802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Hilton Garden Inn St. George',
#               'photos': [{'height': 390,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/105535135526381524133">Hilton '
#                                                 'Garden Inn St. George</a>'],
#                           'photo_reference': 'Aap_uEBY0Wkwn45cJvNgvO0TR-LuJaOdNWdB83yoml091ykCTXUnCDw93-BMfRHewO8yu5zgNXT0unmEN-LDAvJC4iXAPZw8PgjJThb3QfNz-EpgmCnqAjsqS594FJNqekjZIJv-L6W0AC5VMFNospaefKS39UUQ2LtH-v98uPMHWf-yApVi',
#                           'width': 698}],
#               'place_id': 'ChIJl0DXzzdFyoAR96GSwl7RNYo',
#               'plus_code': {'compound_code': '3CH8+9X St. George, UT, USA',
#                             'global_code': '85983CH8+9X'},
#               'rating': 4.3,
#               'reference': 'ChIJl0DXzzdFyoAR96GSwl7RNYo',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 965,
#               'vicinity': '1731 South Convention Center Drive, St. George'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 37.0800183, 'lng': -113.583336},
#                            'viewport': {'northeast': {'lat': 37.0814891802915,
#                                                       'lng': -113.5816876197085},
#                                         'southwest': {'lat': 37.0787912197085,
#                                                       'lng': -113.5843855802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Fairfield Inn by Marriott St. George',
#               'photos': [{'height': 1366,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/106071619236687163542">Fairfield '
#                                                 'Inn by Marriott St. '
#                                                 'George</a>'],
#                           'photo_reference': 'Aap_uEBDVthiFnm1uAUEWRfcgKRQKtv3hXJv7S82WB9ieL61pHu4mbFyaO4rbzwYhIz50UDjINtPv_AyCTkzNmPvaUeElVskNbuvxgJgNpLtARXa189H0e6C-Vs_4HMuplo-VxKFTCZBQDEhVExPd_k1J6QkIe7rlBn7IxEQnJoep7Rb578-',
#                           'width': 2048}],
#               'place_id': 'ChIJVTjqnzdFyoARGA6wky8bq5Y',
#               'plus_code': {'compound_code': '3CJ8+2M St. George, UT, USA',
#                             'global_code': '85983CJ8+2M'},
#               'rating': 4.2,
#               'reference': 'ChIJVTjqnzdFyoARGA6wky8bq5Y',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 571,
#               'vicinity': '1660 South Convention Center Drive, St. George'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 37.110302, 'lng': -113.5804045},
#                            'viewport': {'northeast': {'lat': 37.11153513029149,
#                                                       'lng': -113.5790818197085},
#                                         'southwest': {'lat': 37.10883716970849,
#                                                       'lng': -113.5817797802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Best Western Coral Hills',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2560,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/103642818989353477175">Best '
#                                                 'Western Coral Hills</a>'],
#                           'photo_reference': 'Aap_uECUZhQgcYK2veuGcDMzL-YpmYzbHXc6imLpdiWY3SqSqGJiq0A0vFRJ7vpieMQlntM0i3BX5LAjHR8rVB3N0FEgV4PEjOdj0oUhH0yOsng7KRgbRZa3QzXxAxf7GKmjolz7XfegwIPrAhN44Un1MTq7sAYUxgXlZ-Ke5eJuHBKyqLAf',
#                           'width': 3840}],
#               'place_id': 'ChIJJ4hIQc5EyoARnZ-x7pvO4Og',
#               'plus_code': {'compound_code': '4C69+4R St. George, UT, USA',
#                             'global_code': '85984C69+4R'},
#               'rating': 4.5,
#               'reference': 'ChIJJ4hIQc5EyoARnZ-x7pvO4Og',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 1650,
#               'vicinity': '125 East Saint George Boulevard, St. George'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 37.0870707, 'lng': -113.5831723},
#                            'viewport': {'northeast': {'lat': 37.0884939802915,
#                                                       'lng': -113.5818259197085},
#                                         'southwest': {'lat': 37.0857960197085,
#                                                       'lng': -113.5845238802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'St. George Inn & Suites',
#               'photos': [{'height': 3024,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/102477222191293267071">Dr. '
#                                                 'Ashish Srivastava</a>'],
#                           'photo_reference': 'Aap_uEBlf_gGxdRt9KucaIbk4njV-zsJ2HYwqRwAdvP3FC09mrt8PPZxcdl4PaSxqniPvcM2xHSeIsdGHouR3HLaTmMWDUQQH9cUaybZ2Qfaj4TglBHNZ4yKn2BeTkiv71pT4UcO-TtqKTtctUVX2qjkFMnW2yl6ePPmDyOnCUuxN0tPoMS9',
#                           'width': 4032}],
#               'place_id': 'ChIJe4q9KDBFyoARAaaXuGdGchA',
#               'plus_code': {'compound_code': '3CP8+RP St. George, UT, USA',
#                             'global_code': '85983CP8+RP'},
#               'rating': 4.3,
#               'reference': 'ChIJe4q9KDBFyoARAaaXuGdGchA',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 1390,
#               'vicinity': '1221 South Main Street, St. George'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 37.1088645, 'lng': -113.5556906},
#                            'viewport': {'northeast': {'lat': 37.1103174802915,
#                                                       'lng': -113.5541506197085},
#                                         'southwest': {'lat': 37.1076195197085,
#                                                       'lng': -113.5568485802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Hampton Inn St. George',
#               'photos': [{'height': 608,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/116307631675175515760">Hampton '
#                                                 'Inn St. George</a>'],
#                           'photo_reference': 'Aap_uEDn3ZUIfhXpCGsQ9Mig0PPh2m92xUieuTee94lWLsveNo-k0wZCv40txns_p0PKXeHTgeDKNrdR4ReHyH9aqttlfpidJ-LSGxa7s-0lrwisAkdRVAGJjamgsWWbkMHADZWS__Ei_LAUykvV4p5WpYNrorcBlXPLlQtDVgaJGakLXSsb',
#                           'width': 1080}],
#               'place_id': 'ChIJi26XASRbyoARgf5PZDJwov8',
#               'plus_code': {'compound_code': '4C5V+GP St. George, UT, USA',
#                             'global_code': '85984C5V+GP'},
#               'rating': 4.4,
#               'reference': 'ChIJi26XASRbyoARgf5PZDJwov8',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 1015,
#               'vicinity': '53 River Road, St. George'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 37.1116854, 'lng': -113.5624264},
#                            'viewport': {'northeast': {'lat': 37.1130545302915,
#                                                       'lng': -113.5610300197085},
#                                         'southwest': {'lat': 37.1103565697085,
#                                                       'lng': -113.5637279802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Motel 6 Saint George, UT',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 270,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/108044178249710711273">Motel '
#                                                 '6 Saint George, UT</a>'],
#                           'photo_reference': 'Aap_uEDE5H-EkuLo-ECKeT-S7wBuR8BCuYjKHk-8VoF-6l2UIOXlERQggdul8gxsUaEdNtncH5isIsR3iY0WiwLOLQBKHJTR7h4HlYoyGvTL5BDOxFXtQ3Tn4IETfzw5dNkgHFjUVSrIEcREQynWeFkfqqpuTiZBlP_zunUjkr-95xmrvBKI',
#                           'width': 480}],
#               'place_id': 'ChIJZwDhZC9byoARh8tvv1YWb20',
#               'plus_code': {'compound_code': '4C6Q+M2 St. George, UT, USA',
#                             'global_code': '85984C6Q+M2'},
#               'rating': 3.4,
#               'reference': 'ChIJZwDhZC9byoARh8tvv1YWb20',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 1570,
#               'vicinity': '205 North 1000 East, St. George'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 37.110894, 'lng': -113.5612853},
#                            'viewport': {'northeast': {'lat': 37.1122517302915,
#                                                       'lng': -113.5602695697085},
#                                         'southwest': {'lat': 37.1095537697085,
#                                                       'lng': -113.5629675302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Days Inn by Wyndham St. George',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 400,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/113955445133054553739">Days '
#                                                 'Inn by Wyndham St. '
#                                                 'George</a>'],
#                           'photo_reference': 'Aap_uEB3bKfyBy5rwGZ7Wzd0wQ1pJvTpV4edKF6nP9rc1nMIqyKzzBg0_Z18CPIcYeBuMGnfkCJI3X4N1F0iUnDEdd4iDd1c2TpCsedKtSO0hA4qgHZb3TyuhM8IkR2mM_A7H8N1JBjL0BpDxTUtKNiBzyP_kaLE9i86kMg5webl5UOx1Kuo',
#                           'width': 711}],
#               'place_id': 'ChIJme-vli9byoARYMVUI7VVt3s',
#               'plus_code': {'compound_code': '4C6Q+9F St. George, UT, USA',
#                             'global_code': '85984C6Q+9F'},
#               'rating': 3.6,
#               'reference': 'ChIJme-vli9byoARYMVUI7VVt3s',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 568,
#               'vicinity': '150 North 1000 East, St. George'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 37.0905272, 'lng': -113.5840566},
#                            'viewport': {'northeast': {'lat': 37.0918547802915,
#                                                       'lng': -113.5824073697085},
#                                         'southwest': {'lat': 37.0891568197085,
#                                                       'lng': -113.5851053302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Howard Johnson by Wyndham St. George Hotel & Suites',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 400,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/105846980979438562950">Howard '
#                                                 'Johnson by Wyndham St. George '
#                                                 'Hotel &amp; Suites</a>'],
#                           'photo_reference': 'Aap_uED_8sKdfApW4iu4LKatvgMtXxebxFDQ8K5MTDZoczjXa8CfrLm-wuh9GIjqsHbT_o0B8MIvc8PWt9IjNSJDjCLNTVuYfomCc7yU3ECbx7gnAXFgBRPe3zYOI_eRbx88mq_igrBkvXKvwHfgdOskYHcFhfEGSQ7qXhXLORN21d7MZr7V',
#                           'width': 711}],
#               'place_id': 'ChIJcUwWdC9FyoAReR3OZJDpQpE',
#               'plus_code': {'compound_code': '3CR8+69 St. George, UT, USA',
#                             'global_code': '85983CR8+69'},
#               'rating': 3.7,
#               'reference': 'ChIJcUwWdC9FyoAReR3OZJDpQpE',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 483,
#               'vicinity': '1040 South Main Street, St. George'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 37.09143400000001,
#                                         'lng': -113.623541},
#                            'viewport': {'northeast': {'lat': 37.0931451302915,
#                                                       'lng': -113.6218624697085},
#                                         'southwest': {'lat': 37.0904471697085,
#                                                       'lng': -113.6245604302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Green Valley Spa & Resort',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2448,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/111788751102134064367">Green '
#                                                 'Valley Spa &amp; Resort</a>'],
#                           'photo_reference': 'Aap_uEDLlB0-cecsJqaFioa--DLZkzTteosb3mm2zf40K7M1SOrTFTsd_I3G-KPrbViNZFexc9o9vM1x8Atl4xLfPbx8EPc-JErwf7WRdfDvitaO7IvDWfaffPJJe8EkE1sdxR04aE5LwIx1extj_Hbu5Ke2TMm_AFz2cPLw4QIwGw0BYeAs',
#                           'width': 3264}],
#               'place_id': 'ChIJocgAjlREyoARa5nGvOJ7xVA',
#               'plus_code': {'compound_code': '39RG+HH St. George, UT, USA',
#                             'global_code': '859839RG+HH'},
#               'rating': 4.2,
#               'reference': 'ChIJocgAjlREyoARa5nGvOJ7xVA',
#               'scope': 'GOOGLE',
#               'types': ['spa',
#                         'lodging',
#                         'restaurant',
#                         'food',
#                         'gym',
#                         'health',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'user_ratings_total': 89,
#               'vicinity': '1871 West Canyon View Drive, St. George'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 37.1095827, 'lng': -113.5736436},
#                            'viewport': {'northeast': {'lat': 37.1110429802915,
#                                                       'lng': -113.5725251697085},
#                                         'southwest': {'lat': 37.1083450197085,
#                                                       'lng': -113.5752231302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Econo Lodge',
#               'photos': [{'height': 2304,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/117492622018849549242">Econo '
#                                                 'Lodge</a>'],
#                           'photo_reference': 'Aap_uEBq_2EFKsGwOHVKsaB9jkgaKpPiB-ITeJloiw1r_erLu0AbBsmJhFaGFNgOeNyosRZ-jAJxP8nDNheB2tiNPF-1i3OkYChbp81fWTRjn3dFrmvH-OIZ5RxAEvVMsKkuUzVWe4Y2rHUTaGfJl5HbPX9MGze6VzgxFz4CcQ_bNjmhuq_a',
#                           'width': 2880}],
#               'place_id': 'ChIJ7Z6uqNJEyoARKQ7cAc_sCkU',
#               'plus_code': {'compound_code': '4C5G+RG St. George, UT, USA',
#                             'global_code': '85984C5G+RG'},
#               'rating': 3.6,
#               'reference': 'ChIJ7Z6uqNJEyoARKQ7cAc_sCkU',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 445,
#               'vicinity': '460 East Saint George Boulevard, St. George'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 37.1037937, 'lng': -113.5510682},
#                            'viewport': {'northeast': {'lat': 37.1052679302915,
#                                                       'lng': -113.5498507197085},
#                                         'southwest': {'lat': 37.1025699697085,
#                                                       'lng': -113.5525486802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'TownePlace Suites by Marriott St. George',
#               'photos': [{'height': 1366,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/105823104866821811650">TownePlace '
#                                                 'Suites by Marriott St. '
#                                                 'George</a>'],
#                           'photo_reference': 'Aap_uEBgC0Nx5Ko6dka5d3O-lPiDRrBcZf_RJSe0fktNRHHGM5k5PySQm5SIY_sSqX-_Vg4BAucaCTIKlz1SuGZ5vPFdvZUFaVi9DgiLX-W7mqGvCIhzRGyqrsRDtxQJzK6lOmiTNuyU9jMtumIfqJLiSWw1rEK9upBMum75dmFkYFlM6y-x',
#                           'width': 2048}],
#               'place_id': 'ChIJcV27hiBbyoAR44s4MWkAp7k',
#               'plus_code': {'compound_code': '4C3X+GH St. George, UT, USA',
#                             'global_code': '85984C3X+GH'},
#               'rating': 4.4,
#               'reference': 'ChIJcV27hiBbyoAR44s4MWkAp7k',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 438,
#               'vicinity': '251 South 1470 East, St. George'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 37.10948199999999,
#                                         'lng': -113.576598},
#                            'viewport': {'northeast': {'lat': 37.11099643029149,
#                                                       'lng': -113.5752493697085},
#                                         'southwest': {'lat': 37.10829846970849,
#                                                       'lng': -113.5779473302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Aiden By Best Western @ St. George',
#               'photos': [{'height': 3078,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/116757736699456638213">Aiden '
#                                                 'By Best Western @ St. '
#                                                 'George</a>'],
#                           'photo_reference': 'Aap_uEAuy8Alk5zeD7Nbxdt0MuSDyAoXi_DojxFzmArpe0ykbrpMfbtGHzSt6p5Vwbhn0dTmhJdbhlm-JZXDXGdAQdd9mm1ID9f-lYm-H0aQ5jHFYAPHttYljJVIjRq0h1GrkE4iZzMOkTyM9BLxI0Is3LwATrGW70R4EvzcATSGfLhry1RS',
#                           'width': 5472}],
#               'place_id': 'ChIJw-mEhc1EyoARl6FZNYH0ntE',
#               'plus_code': {'compound_code': '4C5F+Q9 St. George, UT, USA',
#                             'global_code': '85984C5F+Q9'},
#               'rating': 4.5,
#               'reference': 'ChIJw-mEhc1EyoARl6FZNYH0ntE',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 647,
#               'vicinity': '316 East Saint George Boulevard, St. George'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 37.11032, 'lng': -113.571539},
#                            'viewport': {'northeast': {'lat': 37.1115537302915,
#                                                       'lng': -113.5701036697085},
#                                         'southwest': {'lat': 37.10885576970851,
#                                                       'lng': -113.5728016302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Coronada Inn & Suites',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 3096,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/102929702910373214489">Gabby '
#                                                 'Grimoldi</a>'],
#                           'photo_reference': 'Aap_uECQ6lE1gZupNuEtOaC2oL9AzWZAOkYAKpmkTgDnGsi4_3lno5GHzzv-I99plRdOXJ2AnvVrgE1Yh_7NJHrx_GYFVFt4Fvh6HcP06XruWvNGcutjMdseV2kWnDCtzc_nZKzZ_EW0SYJ2-Sc0oGD-wPBlqtHfNmodWa0pAORCzySxMUqQ',
#                           'width': 4128}],
#               'place_id': 'ChIJGztkXS1byoARo3znSWrs6w8',
#               'plus_code': {'compound_code': '4C6H+49 St. George, UT, USA',
#                             'global_code': '85984C6H+49'},
#               'rating': 3.1,
#               'reference': 'ChIJGztkXS1byoARo3znSWrs6w8',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 496,
#               'vicinity': '559 East Saint George Boulevard, St. George'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 37.1101567, 'lng': -113.5711686},
#                            'viewport': {'northeast': {'lat': 37.1115094802915,
#                                                       'lng': -113.5697675197085},
#                                         'southwest': {'lat': 37.1088115197085,
#                                                       'lng': -113.5724654802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Sands Motel',
#               'photos': [{'height': 3411,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/117316237349576650327">bepi '
#                                                 'a.</a>'],
#                           'photo_reference': 'Aap_uECbWUS0Z6ypVX14tpBS-2URSvibvXImlgXmo6K_o3d2BrJHcadbMXLFbaLyn5BuaZk8rWheJ3Sed6t_VFLItxeLK91IXlHC8qyr0qczQUlPvinaMGFFLlPa7MYRRrKZgD70-fohRu8nxLve6b3FXlnVs7jqzKZiiOl4ipFhXkejAvaj',
#                           'width': 5744}],
#               'place_id': 'ChIJKyKwWy1byoARil8rZZxMJEs',
#               'plus_code': {'compound_code': '4C6H+3G St. George, UT, USA',
#                             'global_code': '85984C6H+3G'},
#               'rating': 2.7,
#               'reference': 'ChIJKyKwWy1byoARil8rZZxMJEs',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 295,
#               'vicinity': '581 East East Saint George Boulevard, St. George'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 37.0808, 'lng': -113.580471},
#                            'viewport': {'northeast': {'lat': 37.08236813029149,
#                                                       'lng': -113.5790647197085},
#                                         'southwest': {'lat': 37.0796701697085,
#                                                       'lng': -113.5817626802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Comfort Inn At Convention Center',
#               'photos': [{'height': 1916,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/113546286780723768323">Comfort '
#                                                 'Inn At Convention Center</a>'],
#                           'photo_reference': 'Aap_uEAJuqOWHo4_SuZHla1KQo_o1Xm9k5WPaCY2z-QcSX0mSjun9iVKlasLxBOxwOPElWY48-YcpXfmzZotpJFn5UqhZhPVeYArbp4YVarb9u2IgfnyU18QuWFIMngXA116Y3iVtjkwaHxX3HCeMzibQoqhTNNi8szDsRv8RPb-pZCfIExV',
#                           'width': 2880}],
#               'place_id': 'ChIJpQCL7TZFyoARvaisRvDvHiI',
#               'plus_code': {'compound_code': '3CJ9+8R St. George, UT, USA',
#                             'global_code': '85983CJ9+8R'},
#               'rating': 4.2,
#               'reference': 'ChIJpQCL7TZFyoARvaisRvDvHiI',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 656,
#               'vicinity': '138 East Riverside Drive, St. George'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 37.11002629999999,
#                                         'lng': -113.5719183},
#                            'viewport': {'northeast': {'lat': 37.1113760802915,
#                                                       'lng': -113.5704968697085},
#                                         'southwest': {'lat': 37.1086781197085,
#                                                       'lng': -113.5731948302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Economy Inn & Suites',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1536,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/110112936094776666426">Rosemarie '
#                                                 'Alvera</a>'],
# ...
#               'name': 'Beta Trijaya Hotel',
#               'place_id': 'ChIJn8ZCk1buCC4RCN__-g6bUPk',
#               'plus_code': {'compound_code': '8J6C+MX Mendawai, West '
#                                              'Kotawaringin Regency, Central '
#                                              'Kalimantan, Indonesia',
#                             'global_code': '6P9H8J6C+MX'},
#               'reference': 'ChIJn8ZCk1buCC4RCN__-g6bUPk',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'vicinity': 'Jalan Pakunegara No.28-A, Mendawai'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -2.677818199999999,
#                                         'lng': 111.6220724},
#                            'viewport': {'northeast': {'lat': -2.676373869708498,
#                                                       'lng': 111.6233524302915},
#                                         'southwest': {'lat': -2.679071830291502,
#                                                       'lng': 111.6206544697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Warung dendi',
#               'photos': [{'height': 3000,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/108399481607108157807">Dendi '
#                                                 'Saputra</a>'],
#                           'photo_reference': 'Aap_uECevJPyNyHCLVr-KSGYQ3yT2I_MJRHVyC4hjJI4h6H-8b9xcjdGZkQoLe254dsTpBKgVtGwXT2ulxXgtpuVZ0yXsMj61-Op0-lyMENFOarZ1iXzUd6NW1JYqhdObgf-8LE1l8otyyPYssfmaSjvMaefDs8LxCuMq-cqkk9599LdzvvQ',
#                           'width': 4000}],
#               'place_id': 'ChIJ5_scCk7vCC4Re7X1FrkAz3M',
#               'reference': 'ChIJ5_scCk7vCC4Re7X1FrkAz3M',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'vicinity': '8JCC+VRG, Mendawai Seberang'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -2.688962, 'lng': 111.622398},
#                            'viewport': {'northeast': {'lat': -2.687766419708498,
#                                                       'lng': 111.6236775802915},
#                                         'southwest': {'lat': -2.690464380291501,
#                                                       'lng': 111.6209796197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Rupah',
#               'place_id': 'ChIJeyKAs1HvCC4RyTJDI8No_ek',
#               'reference': 'ChIJeyKAs1HvCC4RyTJDI8No_ek',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'vicinity': '8J6C+CX6, Mendawai'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -2.6916867, 'lng': 111.6171318},
#                            'viewport': {'northeast': {'lat': -2.690732319708498,
#                                                       'lng': 111.6186705802915},
#                                         'southwest': {'lat': -2.693430280291502,
#                                                       'lng': 111.6159726197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'BTN CILIK RIWUT',
#               'photos': [{'height': 2592,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/106792853445367488336">risa '
#                                                 'ahmad</a>'],
#                           'photo_reference': 'Aap_uEDVx3Cw9kC6UJ3ymUhUslzXE1BnzOMxMAy5dqgFNxqllexvvUMpgukILpNKqvXFuH0bE8m85VHcvRO1IeXJfT6irLtmHaWUxn_BIN8i8LjN_Jy84wRaVb1hxn8HdDgqh5NFrHTn8s0z8-3fbJQ5qn7m8XvIGWu62RbXbwNHyotQ9rtQ',
#                           'width': 4608}],
#               'place_id': 'ChIJ2xlgOY7vCC4RzBT0CViByis',
#               'plus_code': {'compound_code': '8J58+8V Sidorejo, West '
#                                              'Kotawaringin Regency, Central '
#                                              'Kalimantan, Indonesia',
#                             'global_code': '6P9H8J58+8V'},
#               'rating': 4.6,
#               'reference': 'ChIJ2xlgOY7vCC4RzBT0CViByis',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 5,
#               'vicinity': 'Jalan Cilik Riwut 1, Sidorejo'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -2.6885495, 'lng': 111.624227},
#                            'viewport': {'northeast': {'lat': -2.687141769708498,
#                                                       'lng': 111.6256278302915},
#                                         'southwest': {'lat': -2.689839730291502,
#                                                       'lng': 111.6229298697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Sukirpatie',
#               'photos': [{'height': 1080,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/101459618700569134336">Sukir '
#                                                 'patie</a>'],
#                           'photo_reference': 'Aap_uEDSogFzbfcgPWQtB9R1v4fVrv80QwAwOvhNjvS3zYmLJa15mOyiKARnI1grby8ZEMzN5hi6oK_iaciF5rXDcoXy7KkhTMDQ-dPDe56-WmOJJP9L6CXnALoNuRILsT6Yl8GyDOlAxW6-Ee8z9zWkgnzYUVcfR693XQCs2e4AfhyXSyfY',
#                           'width': 1920}],
#               'place_id': 'ChIJdRJvA53vCC4R5PBsjEWOKcw',
#               'plus_code': {'compound_code': '8J6F+HM Sidorejo, West '
#                                              'Kotawaringin Regency, Central '
#                                              'Kalimantan, Indonesia',
#                             'global_code': '6P9H8J6F+HM'},
#               'rating': 4,
#               'reference': 'ChIJdRJvA53vCC4R5PBsjEWOKcw',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 1,
#               'vicinity': 'Perumnas bukit asri, Jalan Abdul Ancis No.135, '
#                           'RW.rt 10Kec, Sidorejo'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -2.6790255, 'lng': 111.6250711},
#                            'viewport': {'northeast': {'lat': -2.677645769708498,
#                                                       'lng': 111.6263914802915},
#                                         'southwest': {'lat': -2.680343730291502,
#                                                       'lng': 111.6236935197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Mess Matahari',
#               'photos': [{'height': 3096,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/101331575858936656512">Norhalimah '
#                                                 'Tustaiyah</a>'],
#                           'photo_reference': 'Aap_uEAue4A3OIalyMPwH4XddU8oD1ty_21a_WmYtcSmJu3FYgQPqHfAoP2GLwmyyFOQx6P_bWZv8W1q47QgVsMkNiKWF9Qzo6qvV4ASQPHcfcfjf-u2QmVlrx4NAxeJjortHn3z69tOPLMh2vOimolI2sJs3_B0nUgs-Yq67lSKYrwNnXA1',
#                           'width': 4128}],
#               'place_id': 'ChIJjYqAFlzuCC4RRxJAMDxnW0g',
#               'plus_code': {'compound_code': '8JCG+92 Mendawai, West '
#                                              'Kotawaringin Regency, Central '
#                                              'Kalimantan, Indonesia',
#                             'global_code': '6P9H8JCG+92'},
#               'rating': 4.4,
#               'reference': 'ChIJjYqAFlzuCC4RRxJAMDxnW0g',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 111,
#               'vicinity': 'jl pangeran antasari no 4 Rt 13 Rw 05, Mendawai'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -2.6833736, 'lng': 111.6260964},
#                            'viewport': {'northeast': {'lat': -2.681973969708498,
#                                                       'lng': 111.6274624302915},
#                                         'southwest': {'lat': -2.684671930291502,
#                                                       'lng': 111.6247644697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Hotel Andika pangkalan bun',
#               'photos': [{'height': 3472,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/116267685428453931858">joko '
#                                                 'susilo</a>'],
#                           'photo_reference': 'Aap_uEBHCGx7urYxol5uNfxt6zF7pjSctUIEjGOjgBgNx9ME_3ld0vR9L5EDtlp9i_EagxCSV9xj0yfCRScGz8ysx5OcIIB_NA4w40bNd4QSxclFpngnwyn416-fixm0hY17XX_CJRfIPAUrx6JbsCmARPEZQwsj5xA-TgqxxG4eaHC13Rxf',
#                           'width': 4624}],
#               'place_id': 'ChIJwzAm7jTvCC4RFcP37twXgb4',
#               'plus_code': {'compound_code': '8J8G+MC Mendawai, West '
#                                              'Kotawaringin Regency, Central '
#                                              'Kalimantan, Indonesia',
#                             'global_code': '6P9H8J8G+MC'},
#               'rating': 4.6,
#               'reference': 'ChIJwzAm7jTvCC4RFcP37twXgb4',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 10,
#               'vicinity': 'Jalan Hasanudin, Mendawai'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -2.6816825, 'lng': 111.6283093},
#                            'viewport': {'northeast': {'lat': -2.680427569708498,
#                                                       'lng': 111.6295438802915},
#                                         'southwest': {'lat': -2.683125530291502,
#                                                       'lng': 111.6268459197085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'BARAKAN SERASIH',
#               'photos': [{'height': 4000,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/110428305914918884145">Haryo '
#                                                 'channel</a>'],
#                           'photo_reference': 'Aap_uEAw0gmZw8rg0X2bKRIAQh9i8n75cwtFOuU0PiU3QgcO1Xlu5L83ReQQhfCalmqnzcKrHjOunZZwkH2Bh5yXYJcHbeFw4KBPtf7woyOgRt7MyW3AdUDAgk8LZMui4kYDHGAklGTFtvoLuS2k4ZvUS7UOq4dOWXukIt27BIQyfK7cKoYW',
#                           'width': 3000}],
#               'place_id': 'ChIJA2qmytnvCC4REAvfi02VIIk',
#               'plus_code': {'compound_code': '8J9H+88 Mendawai, West '
#                                              'Kotawaringin Regency, Central '
#                                              'Kalimantan, Indonesia',
#                             'global_code': '6P9H8J9H+88'},
#               'reference': 'ChIJA2qmytnvCC4REAvfi02VIIk',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'vicinity': 'Jalan DAH Hamzah, Mendawai'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -2.6835413, 'lng': 111.6285157},
#                            'viewport': {'northeast': {'lat': -2.682173619708498,
#                                                       'lng': 111.6298067302915},
#                                         'southwest': {'lat': -2.684871580291501,
#                                                       'lng': 111.6271087697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Bone Hotel',
#               'photos': [{'height': 1920,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/106532733198614195855">A2_Rossi '
#                                                 'Apriliani Dewi_2021</a>'],
#                           'photo_reference': 'Aap_uECu0PvzuRgZLNASPSLPUAvWkl2Rya0R7uck6y4BMTwKkuGXC8Vjh9epw9n1xqLz00dH6UedBfpKDdQHqqNzYclr7uyqHBuERHM_y4Z46ZE-d2xXihMyzuhWFEbdBhQ60BDHWEfnwjvRlcgy2U5MfQkWsCIdQaejgxMDaxHwUnTzOdrb',
#                           'width': 1080}],
#               'place_id': 'ChIJn8ZCk1buCC4RlY6HwjS_ZaQ',
#               'plus_code': {'compound_code': '8J8H+HC Sidorejo, West '
#                                              'Kotawaringin Regency, Central '
#                                              'Kalimantan, Indonesia',
#                             'global_code': '6P9H8J8H+HC'},
#               'rating': 3.9,
#               'reference': 'ChIJn8ZCk1buCC4RlY6HwjS_ZaQ',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 41,
#               'vicinity': 'Jalan Domba No.21, Sidorejo'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -2.676583, 'lng': 111.626448},
#                            'viewport': {'northeast': {'lat': -2.675369569708498,
#                                                       'lng': 111.6278937302915},
#                                         'southwest': {'lat': -2.678067530291502,
#                                                       'lng': 111.6251957697085}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Hotl Tiara',
#               'place_id': 'ChIJXV1kvV3uCC4Re_tQp2nUSyU',
#               'rating': 3.3,
#               'reference': 'ChIJXV1kvV3uCC4Re_tQp2nUSyU',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 3,
#               'vicinity': '8JFG+9H8, Mendawai'}],
#  'status': 'OK'}

# %%
print(len(hotel_df.index))
# Out:
# 403

# %%
hotel_df.head(20)
# Out:
#                  City Country  Max Temp Current Description      Lat  \
# index_
# 0            Belmonte      BR     77.50       moderate rain -15.8631
# 1        Saint George      US     50.47           clear sky  37.1041
# 2              Avarua      CK     75.25    scattered clouds -21.2078
# 3           Kathmandu      NP     46.62          few clouds  27.7167
# 4           Busselton      AU     72.09           clear sky -33.6500
# 5             Rikitea      PF     77.07     overcast clouds -23.1203
# 6       Pangkalanbuun      ID     76.55     overcast clouds  -2.6833
# 7           Taoudenni      ML     80.53     overcast clouds  22.6783
# 8             Ushuaia      AR     58.66    scattered clouds -54.8000
# 9            Hermanus      ZA     80.80           clear sky -34.4187
# 10               Lebu      CL     64.40    scattered clouds -37.6167
# 11              Bluff      NZ     61.81     overcast clouds -46.6000
# 12              Kapaa      US     73.72          light rain  22.0752
# 13        East London      ZA     74.34    scattered clouds -33.0153
# 14              Kieta      PG     79.88     overcast clouds  -6.2167
# 15             Ghanzi      BW     80.98     overcast clouds -21.5667
# 16         Luganville      VU     78.62          light rain -15.5333
# 17         Punta Alta      AR     84.65           clear sky -38.8759
# 18              Vaini      TO     80.96          light rain -21.2000
# 19      Mar Del Plata      AR     78.82           clear sky -38.0023
#
#              Lng                   Hotel Name
# index_
# 0       -38.8828  Pousada Monte Carmelo O Pão
# 1      -113.5841  Best Western Plus Abbey Inn
# 2      -159.7750                 Paradise Inn
# 3        85.3167      Hotel Shanker Kathmandu
# 4       115.3333      Observatory Guest House
# 5      -134.9692              People ThankYou
# 6       111.6167         Grand Kecubung Hotel
# 7        -3.9836
# 8       -68.3000
# 9        19.2345
# 10      -73.6500
# 11      168.3333
# 12     -159.3190
# 13       27.9116
# 14      155.6333
# 15       21.7833
# 16      167.1667
# 17      -62.0736
# 18     -175.2000
# 19      -57.5575

# %%
# 7. Drop the rows where there is no Hotel Name.
hotel_df = hotel_df.loc[hotel_df['Hotel Name'] != '']

# %%
hotel_df
# Out:
#                  City Country  Max Temp Current Description      Lat  \
# index_
# 0            Belmonte      BR     77.50       moderate rain -15.8631
# 1        Saint George      US     50.47           clear sky  37.1041
# 2              Avarua      CK     75.25    scattered clouds -21.2078
# 3           Kathmandu      NP     46.62          few clouds  27.7167
# 4           Busselton      AU     72.09           clear sky -33.6500
# 5             Rikitea      PF     77.07     overcast clouds -23.1203
# 6       Pangkalanbuun      ID     76.55     overcast clouds  -2.6833
#
#              Lng                   Hotel Name
# index_
# 0       -38.8828  Pousada Monte Carmelo O Pão
# 1      -113.5841  Best Western Plus Abbey Inn
# 2      -159.7750                 Paradise Inn
# 3        85.3167      Hotel Shanker Kathmandu
# 4       115.3333      Observatory Guest House
# 5      -134.9692              People ThankYou
# 6       111.6167         Grand Kecubung Hotel

# %%
# 8a. Create the output File (CSV)


# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """

"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 

# 11b. Display the figure
