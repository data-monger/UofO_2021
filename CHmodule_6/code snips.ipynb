# %%
import random
import timeit
import time

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import requests as req
import json

from pprint import pprint as p
from citipy import citipy
from datetime import datetime as dt


from config import g_api_key
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
def lats(size_):
    lats = []
    lats = np.random.uniform(low=-90, high=90, size=size_)
    return lats

def lngs(size_):
    lngs = []
    lngs = np.random.uniform(low=-180, high=180, size=size_)
    return lngs

lats_lngs = zip(lats(100), lngs(100))

coords = list(lats_lngs)
coords
# Out:
# [(-8.516234286933226, 84.8046755230946),
#  (46.57859469131017, 78.527899233644),
#  (21.49449551654554, 166.53738797528433),
#  (9.881018007979918, 44.16932225673844),
#  (-33.774945247378945, -169.02091441850033),
#  (79.14559463111402, 132.31954778967463),
#  (-56.239830747321285, 91.43646209613695),
#  (23.686762807876576, 38.81176443654752),
#  (9.045837756244396, 23.748131952225236),
#  (-47.88159220428368, -176.94532431393137),
#  (64.13608179715291, 159.51607852109674),
#  (-87.85412723650639, 10.779865844624027),
#  (-7.318516155033279, -86.62351156102132),
#  (1.653998122182088, 122.46315392193861),
#  (23.25424353896888, -60.05460192999966),
#  (-83.61280615365725, 33.97706180646529),
#  (-16.070568124261783, -31.592307453301544),
#  (-77.40405503920913, -39.51621149656111),
#  (-83.08982420460494, 56.677696694654685),
#  (-49.69683341815388, -124.14920915590481),
#  (-24.991460321447406, 83.31506745693571),
#  (65.27065126509038, 166.4029730510066),
#  (-46.03912260255968, 100.44849916806533),
#  (61.26008096456343, -102.64925712308468),
#  (-7.191615861123012, -13.702664443308578),
#  (-0.6566897642635325, -12.085947286291685),
#  (61.87640625390563, 178.43486889343927),
#  (48.36485668030494, -142.26057777337834),
#  (-37.73960772933799, 137.00940292496193),
#  (-66.73839355120546, 83.94267833808169),
#  (70.08775854631233, 171.5817105451153),
#  (-67.71657523835088, 36.66004704611717),
#  (-32.29405679329876, -54.16425922253296),
#  (69.0808093820225, -96.76707231071666),
#  (-34.541164013244874, 27.85103983733319),
#  (-4.10847387496726, 18.232641116811948),
#  (47.219353798706294, -102.79684175595783),
#  (41.188726807837014, -79.14399718289684),
#  (-6.165515776359129, 178.35428912614378),
#  (15.427387490838242, 123.3294600524597),
#  (80.34929187290757, -4.101091625875483),
#  (-43.152904171601634, -107.4121238899481),
#  (50.3694014511959, -161.81941233745147),
#  (-49.49337393376439, 172.62149462818275),
#  (74.58107818391363, 29.739716385703588),
#  (-87.07552644397849, 149.4086383334719),
#  (60.546270733047635, 145.06353868199562),
#  (-67.19838311602888, -178.83995084559996),
#  (77.55070772351962, 148.9660966253988),
#  (-16.13554991983102, 146.6706805612539),
#  (-88.62901014547107, 87.93322899563384),
#  (-10.572817255805091, -139.2195226763966),
#  (19.584602660768596, 36.88244496050339),
#  (52.46182643318417, 122.71469521002035),
#  (57.33405804494137, -161.8183952879392),
#  (-4.564534394885868, -84.6788933944544),
#  (72.76893555320953, -82.970773462608),
#  (43.39565056612028, -136.15141521816992),
#  (-44.15434886677099, 177.66137836003043),
#  (-62.27110460649726, 123.39016059709235),
#  (39.23046261388296, 157.72883498072957),
#  (40.543839823868836, 79.61516971289723),
#  (63.93667602572788, -77.77886593987851),
#  (-36.066240721219984, -37.10365237359537),
#  (7.448848687879391, 109.03755197810892),
#  (-33.82902124949728, 113.1667814194958),
#  (1.6867063830164994, -138.37765418988488),
#  (-31.266907574977026, -101.33213801136124),
#  (-14.31643922426889, -18.55683046377328),
#  (-7.435065457318473, 73.36043468882283),
#  (87.19829185895054, 107.61731475572776),
#  (-73.01216858312138, 150.53520661197962),
#  (-3.226242563090125, 30.255704144538953),
#  (41.19696614971127, -134.96887197192842),
#  (68.60739871448746, -156.2328351913574),
#  (53.111323992099216, 25.147337744005995),
#  (31.052815954307547, -139.1353980274825),
#  (-1.559185148053885, 170.41786926703548),
#  (-20.740971869258928, 175.3612148440348),
#  (51.35959511608209, -74.35823121011634),
#  (-77.95347529990917, 88.5414018629985),
#  (19.612895361762753, -109.2661286196257),
#  (4.70494543986554, 35.9723265234781),
#  (32.78285402081853, 14.814138556692853),
#  (-65.2780669524114, -43.649999758606924),
#  (21.904248853127314, 150.91941712045968),
#  (71.46085918429739, -85.70266429671206),
#  (-22.67735852332359, -132.31253633328674),
#  (53.508289520558776, -12.147878582633894),
#  (41.3810800131572, 119.455102177794),
#  (68.31124406529352, -45.62004333018098),
#  (42.83496929442438, -93.52640971734705),
#  (72.69843371459936, -28.26159333433273),
#  (-80.09290745864723, -129.63495739195037),
#  (-78.8583676651156, -128.74707149793159),
#  (-6.996050743867102, -107.40225284905279),
#  (-18.559844624600302, -16.258235710372702),
#  (-46.07628879566732, -102.35281253221221),
#  (76.98674468235274, -33.83376878139592),
#  (-2.7715756356398202, 71.57974134591348)]

# %%
cities = []

for coordinate in coords:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    if city not in cities:
        cities.append(city)
    
len(cities)
cities
# Out:
# ['hithadhoo',
#  'ushtobe',
#  'butaritari',
#  'hargeysa',
#  'vaini',
#  'tiksi',
#  'busselton',
#  'umm lajj',
#  'birao',
#  'evensk',
#  'hermanus',
#  'paita',
#  'gorontalo',
#  'the valley',
#  'port elizabeth',
#  'belmonte',
#  'ushuaia',
#  'east london',
#  'rikitea',
#  'grand river south east',
#  'kamenskoye',
#  'flin flon',
#  'georgetown',
#  'harper',
#  'beringovskiy',
#  'sitka',
#  'victor harbor',
#  'pevek',
#  'port alfred',
#  'melo',
#  'thompson',
#  'bulungu',
#  'dickinson',
#  'indiana',
#  'asau',
#  'jomalig',
#  'klaksvik',
#  'castro',
#  'bethel',
#  'dunedin',
#  'berlevag',
#  'hobart',
#  'okhotsk',
#  'chokurdakh',
#  'cairns',
#  'albany',
#  'atuona',
#  'sawakin',
#  'urusha',
#  'talara',
#  'qaanaaq',
#  'port hardy',
#  'waipawa',
#  'sentyabrskiy',
#  'aksu',
#  'iqaluit',
#  'laguna',
#  'vung tau',
#  'lebu',
#  'khatanga',
#  'karuzi',
#  'eureka',
#  'barrow',
#  'slonim',
#  'fortuna',
#  'tabiauea',
#  'isangel',
#  'chapais',
#  'cabo san lucas',
#  'jinka',
#  'zlitan',
#  'katsuura',
#  'clyde river',
#  'dingle',
#  'lingyuan',
#  'ilulissat',
#  'mason city',
#  'illoqqortoormiut',
#  'puerto ayora',
#  'tasiilaq']

# %%
# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list
for i, city in enumerate(cities):
    ### 60 calls per minute
    time.sleep(2)
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
#    print(city_url)
#    break
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count += 1
    # Run an API request for each of the cities
    try:
        city_weather = req.get(city_url).json()
        p(city_weather)        
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        try:
            city_rain_inches = city_weather["rain"]["1h"]
        except KeyError:
            city_rain_inches = 0
        try:
            city_snow_inches = city_weather["snow"]["1h"]
        except KeyError:
            city_snow_inches = 0
            # Append the City information into city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Rain (inches)": city_rain_inches,
                          "Snow (inches)": city_snow_inches,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | hithadhoo
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -0.6, 'lon': 73.0833},
#  'dt': 1643330184,
#  'id': 1282256,
#  'main': {'feels_like': 84.61,
#           'grnd_level': 1008,
#           'humidity': 70,
#           'pressure': 1009,
#           'sea_level': 1009,
#           'temp': 81,
#           'temp_max': 81,
#           'temp_min': 81},
#  'name': 'Hithadhoo',
#  'sys': {'country': 'MV', 'sunrise': 1643332569, 'sunset': 1643376283},
#  'timezone': 18000,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 355, 'gust': 14.97, 'speed': 14.54}}
# Processing Record 2 of Set 1 | ushtobe
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 45.2514, 'lon': 77.9838},
#  'dt': 1643330187,
#  'id': 1517637,
#  'main': {'feels_like': 1.51,
#           'grnd_level': 973,
#           'humidity': 88,
#           'pressure': 1028,
#           'sea_level': 1028,
#           'temp': 14.11,
#           'temp_max': 14.11,
#           'temp_min': 14.11},
#  'name': 'Ushtobe',
#  'sys': {'country': 'KZ', 'sunrise': 1643336002, 'sunset': 1643370497},
#  'timezone': 21600,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 62, 'gust': 16.37, 'speed': 10.07}}
# Processing Record 3 of Set 1 | butaritari
# {'base': 'stations',
#  'clouds': {'all': 2},
#  'cod': 200,
#  'coord': {'lat': 3.0707, 'lon': 172.7902},
#  'dt': 1643330189,
#  'id': 2110227,
#  'main': {'feels_like': 88.75,
#           'grnd_level': 1007,
#           'humidity': 77,
#           'pressure': 1008,
#           'sea_level': 1008,
#           'temp': 82.31,
#           'temp_max': 82.31,
#           'temp_min': 82.31},
#  'name': 'Butaritari',
#  'sys': {'country': 'KI', 'sunrise': 1643308927, 'sunset': 1643352059},
#  'timezone': 43200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 74, 'gust': 17.9, 'speed': 15.68}}
# Processing Record 4 of Set 1 | hargeysa
# {'base': 'stations',
#  'clouds': {'all': 35},
#  'cod': 200,
#  'coord': {'lat': 9.56, 'lon': 44.065},
#  'dt': 1643330192,
#  'id': 57289,
#  'main': {'feels_like': 52.12,
#           'grnd_level': 876,
#           'humidity': 57,
#           'pressure': 1016,
#           'sea_level': 1016,
#           'temp': 54.32,
#           'temp_max': 54.32,
#           'temp_min': 54.32},
#  'name': 'Hargeisa',
#  'sys': {'country': 'SO', 'sunrise': 1643340342, 'sunset': 1643382441},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 341, 'gust': 18.92, 'speed': 12.33}}
# Processing Record 5 of Set 1 | vaini
# {'base': 'stations',
#  'clouds': {'all': 21},
#  'cod': 200,
#  'coord': {'lat': -21.2, 'lon': -175.2},
#  'dt': 1643330194,
#  'id': 4032243,
#  'main': {'feels_like': 90.27,
#           'grnd_level': 1009,
#           'humidity': 78,
#           'pressure': 1012,
#           'sea_level': 1012,
#           'temp': 82.83,
#           'temp_max': 82.83,
#           'temp_min': 82.83},
#  'name': 'Vaini',
#  'sys': {'country': 'TO', 'sunrise': 1643390449, 'sunset': 1643437595},
#  'timezone': 46800,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 59, 'gust': 16.69, 'speed': 14.56}}
# Processing Record 6 of Set 1 | tiksi
# {'base': 'stations',
#  'clouds': {'all': 44},
#  'cod': 200,
#  'coord': {'lat': 71.6872, 'lon': 128.8694},
#  'dt': 1643330196,
#  'id': 2015306,
#  'main': {'feels_like': -26.84,
#           'grnd_level': 1016,
#           'humidity': 97,
#           'pressure': 1022,
#           'sea_level': 1022,
#           'temp': -14.24,
#           'temp_max': -14.24,
#           'temp_min': -14.24},
#  'name': 'Tiksi',
#  'sys': {'country': 'RU', 'sunrise': 1643336704, 'sunset': 1643345367},
#  'timezone': 32400,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 234, 'gust': 15.99, 'speed': 10.27}}
# Processing Record 7 of Set 1 | busselton
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -33.65, 'lon': 115.3333},
#  'dt': 1643330199,
#  'id': 2075265,
#  'main': {'feels_like': 66.65,
#           'grnd_level': 1016,
#           'humidity': 45,
#           'pressure': 1016,
#           'sea_level': 1016,
#           'temp': 68.04,
#           'temp_max': 68.04,
#           'temp_min': 67.08},
#  'name': 'Busselton',
#  'sys': {'country': 'AU',
#          'id': 2020551,
#          'sunrise': 1643319375,
#          'sunset': 1643369194,
#          'type': 2},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 93, 'gust': 14.79, 'speed': 11.48}}
# Processing Record 8 of Set 1 | umm lajj
# {'base': 'stations',
#  'clouds': {'all': 57},
#  'cod': 200,
#  'coord': {'lat': 25.0213, 'lon': 37.2685},
#  'dt': 1643330201,
#  'id': 100926,
#  'main': {'feels_like': 56.66,
#           'grnd_level': 1019,
#           'humidity': 44,
#           'pressure': 1019,
#           'sea_level': 1019,
#           'temp': 59,
#           'temp_max': 59,
#           'temp_min': 59},
#  'name': 'Umluj',
#  'sys': {'country': 'SA', 'sunrise': 1643343312, 'sunset': 1643382734},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 1, 'gust': 17.47, 'speed': 14.38}}
# Processing Record 9 of Set 1 | birao
# {'base': 'stations',
#  'clouds': {'all': 99},
#  'cod': 200,
#  'coord': {'lat': 10.2849, 'lon': 22.7882},
#  'dt': 1643330204,
#  'id': 240210,
#  'main': {'feels_like': 65.61,
#           'grnd_level': 960,
#           'humidity': 18,
#           'pressure': 1014,
#           'sea_level': 1014,
#           'temp': 68.23,
#           'temp_max': 68.23,
#           'temp_min': 68.23},
#  'name': 'Birao',
#  'sys': {'country': 'CF', 'sunrise': 1643345507, 'sunset': 1643387490},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 72, 'gust': 32.61, 'speed': 11.07}}
# Processing Record 10 of Set 1 | evensk
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 61.95, 'lon': 159.2333},
#  'dt': 1643330206,
#  'id': 2125693,
#  'main': {'feels_like': 7.03,
#           'grnd_level': 1008,
#           'humidity': 82,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 19.63,
#           'temp_max': 19.63,
#           'temp_min': 19.63},
#  'name': 'Evensk',
#  'sys': {'country': 'RU', 'sunrise': 1643320809, 'sunset': 1643346685},
#  'timezone': 39600,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 49, 'gust': 50.33, 'speed': 36.53}}
# Processing Record 11 of Set 1 | hermanus
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -34.4187, 'lon': 19.2345},
#  'dt': 1643330209,
#  'id': 3366880,
#  'main': {'feels_like': 65.84,
#           'grnd_level': 1010,
#           'humidity': 80,
#           'pressure': 1014,
#           'sea_level': 1014,
#           'temp': 65.8,
#           'temp_max': 65.8,
#           'temp_min': 63.9},
#  'name': 'Hermanus',
#  'sys': {'country': 'ZA',
#          'id': 2006131,
#          'sunrise': 1643342361,
#          'sunset': 1643392342,
#          'type': 2},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 273, 'gust': 4.25, 'speed': 3.29}}
# Processing Record 12 of Set 1 | paita
# {'base': 'stations',
#  'clouds': {'all': 59},
#  'cod': 200,
#  'coord': {'lat': -5.0892, 'lon': -81.1144},
#  'dt': 1643330211,
#  'id': 3694112,
#  'main': {'feels_like': 71.83,
#           'grnd_level': 1009,
#           'humidity': 85,
#           'pressure': 1013,
#           'sea_level': 1013,
#           'temp': 71.04,
#           'temp_max': 71.04,
#           'temp_min': 71.04},
#  'name': 'Paita',
#  'sys': {'country': 'PE', 'sunrise': 1643282808, 'sunset': 1643327245},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 212, 'gust': 12.97, 'speed': 9.98}}
# Processing Record 13 of Set 1 | gorontalo
# {'base': 'stations',
#  'clouds': {'all': 59},
#  'cod': 200,
#  'coord': {'lat': 0.5412, 'lon': 123.0595},
#  'dt': 1643330213,
#  'id': 1643837,
#  'main': {'feels_like': 90.61,
#           'grnd_level': 1011,
#           'humidity': 75,
#           'pressure': 1012,
#           'sea_level': 1012,
#           'temp': 83.35,
#           'temp_max': 83.35,
#           'temp_min': 83.35},
#  'name': 'Gorontalo',
#  'sys': {'country': 'ID', 'sunrise': 1643320663, 'sunset': 1643364197},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 356, 'gust': 3.89, 'speed': 2.42}}
# Processing Record 14 of Set 1 | the valley
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 18.217, 'lon': -63.0578},
#  'dt': 1643330487,
#  'id': 3573374,
#  'main': {'feels_like': 77.29,
#           'grnd_level': 1014,
#           'humidity': 65,
#           'pressure': 1016,
#           'sea_level': 1016,
#           'temp': 76.86,
#           'temp_max': 77.83,
#           'temp_min': 76.86},
#  'name': 'The Valley',
#  'sys': {'country': 'AI',
#          'id': 8801,
#          'sunrise': 1643280380,
#          'sunset': 1643321004,
#          'type': 1},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 66, 'gust': 15.97, 'speed': 15.32}}
# Processing Record 15 of Set 1 | port elizabeth
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -33.918, 'lon': 25.5701},
#  'dt': 1643330701,
#  'id': 964420,
#  'main': {'feels_like': 66.97,
#           'humidity': 88,
#           'pressure': 1011,
#           'temp': 66.49,
#           'temp_max': 67.1,
#           'temp_min': 66.49},
#  'name': 'Port Elizabeth',
#  'sys': {'country': 'ZA',
#          'id': 1973,
#          'sunrise': 1643340901,
#          'sunset': 1643390761,
#          'type': 1},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 280, 'speed': 5.75}}
# Processing Record 16 of Set 1 | belmonte
# {'base': 'stations',
#  'clouds': {'all': 99},
#  'cod': 200,
#  'coord': {'lat': -15.8631, 'lon': -38.8828},
#  'dt': 1643330703,
#  'id': 3470137,
#  'main': {'feels_like': 79,
#           'grnd_level': 1012,
#           'humidity': 86,
#           'pressure': 1012,
#           'sea_level': 1012,
#           'temp': 77.5,
#           'temp_max': 77.5,
#           'temp_min': 77.5},
#  'name': 'Belmonte',
#  'sys': {'country': 'BR',
#          'id': 8422,
#          'sunrise': 1643271765,
#          'sunset': 1643318014,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 59, 'gust': 8.14, 'speed': 6.62}}
# Processing Record 17 of Set 1 | ushuaia
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -54.8, 'lon': -68.3},
#  'dt': 1643330706,
#  'id': 3833367,
#  'main': {'feels_like': 49.64,
#           'humidity': 71,
#           'pressure': 1013,
#           'temp': 51.46,
#           'temp_max': 51.46,
#           'temp_min': 51.46},
#  'name': 'Ushuaia',
#  'sys': {'country': 'AR',
#          'id': 8303,
#          'sunrise': 1643273172,
#          'sunset': 1643330728,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 200, 'speed': 10.36}}
# Processing Record 18 of Set 1 | east london
# {'base': 'stations',
#  'clouds': {'all': 59},
#  'cod': 200,
#  'coord': {'lat': -33.0153, 'lon': 27.9116},
#  'dt': 1643330708,
#  'id': 1006984,
#  'main': {'feels_like': 73.74,
#           'grnd_level': 1003,
#           'humidity': 90,
#           'pressure': 1009,
#           'sea_level': 1009,
#           'temp': 72.55,
#           'temp_max': 72.55,
#           'temp_min': 72.55},
#  'name': 'East London',
#  'rain': {'1h': 0.12},
#  'sys': {'country': 'ZA', 'sunrise': 1643340446, 'sunset': 1643390091},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 235, 'gust': 23, 'speed': 16.53}}
# Processing Record 19 of Set 1 | rikitea
# {'base': 'stations',
#  'clouds': {'all': 74},
#  'cod': 200,
#  'coord': {'lat': -23.1203, 'lon': -134.9692},
#  'dt': 1643330710,
#  'id': 4030556,
#  'main': {'feels_like': 78.71,
#           'grnd_level': 1017,
#           'humidity': 75,
#           'pressure': 1019,
#           'sea_level': 1019,
#           'temp': 78.71,
#           'temp_max': 78.71,
#           'temp_min': 78.71},
#  'name': 'Rikitea',
#  'sys': {'country': 'PF', 'sunrise': 1643294166, 'sunset': 1643341741},
#  'timezone': -32400,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 92, 'gust': 17.81, 'speed': 15.88}}
# Processing Record 20 of Set 1 | grand river south east
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 21 of Set 1 | kamenskoye
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 22 of Set 1 | flin flon
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 54.7682, 'lon': -101.865},
#  'dt': 1643330422,
#  'id': 5954718,
#  'main': {'feels_like': -9.31,
#           'humidity': 66,
#           'pressure': 1023,
#           'temp': 3.04,
#           'temp_max': 3.04,
#           'temp_min': 3.04},
#  'name': 'Flin Flon',
#  'sys': {'country': 'CA',
#          'id': 782,
#          'sunrise': 1643294740,
#          'sunset': 1643325274,
#          'type': 1},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 260, 'speed': 6.91}}
# Processing Record 23 of Set 1 | georgetown
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 5.4112, 'lon': 100.3354},
#  'dt': 1643330592,
#  'id': 1735106,
#  'main': {'feels_like': 78.24,
#           'humidity': 90,
#           'pressure': 1010,
#           'temp': 76.64,
#           'temp_max': 78.89,
#           'temp_min': 74.98},
#  'name': 'George Town',
#  'sys': {'country': 'MY',
#          'id': 2037578,
#          'sunrise': 1643326504,
#          'sunset': 1643369265,
#          'type': 2},
#  'timezone': 28800,
#  'visibility': 8000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 62, 'gust': 1.99, 'speed': 1.99}}
# Processing Record 24 of Set 1 | harper
# {'base': 'stations',
#  'clouds': {'all': 98},
#  'cod': 200,
#  'coord': {'lat': 4.375, 'lon': -7.7169},
#  'dt': 1643330722,
#  'id': 2276492,
#  'main': {'feels_like': 78.85,
#           'grnd_level': 1009,
#           'humidity': 80,
#           'pressure': 1010,
#           'sea_level': 1010,
#           'temp': 78.85,
#           'temp_max': 78.85,
#           'temp_min': 78.85},
#  'name': 'Harper',
#  'sys': {'country': 'LR', 'sunrise': 1643352356, 'sunset': 1643395285},
#  'timezone': 0,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 157, 'gust': 5.82, 'speed': 5.48}}
# Processing Record 25 of Set 1 | beringovskiy
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 63.05, 'lon': 179.3167},
#  'dt': 1643330605,
#  'id': 2126710,
#  'main': {'feels_like': -1.88,
#           'grnd_level': 1028,
#           'humidity': 94,
#           'pressure': 1031,
#           'sea_level': 1031,
#           'temp': 4.42,
#           'temp_max': 4.42,
#           'temp_min': 4.42},
#  'name': 'Beringovskiy',
#  'sys': {'country': 'RU', 'sunrise': 1643316492, 'sunset': 1643341361},
#  'timezone': 43200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 106, 'gust': 3.42, 'speed': 3}}
# Processing Record 26 of Set 1 | sitka
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 57.0531, 'lon': -135.33},
#  'dt': 1643330444,
#  'id': 5557293,
#  'main': {'feels_like': 34.97,
#           'humidity': 75,
#           'pressure': 1011,
#           'temp': 42.69,
#           'temp_max': 42.69,
#           'temp_min': 42.69},
#  'name': 'Sitka',
#  'rain': {'1h': 1.02},
#  'sys': {'country': 'US',
#          'id': 7795,
#          'sunrise': 1643303393,
#          'sunset': 1643332687,
#          'type': 1},
#  'timezone': -32400,
#  'visibility': 8047,
#  'weather': [{'description': 'moderate rain',
#               'icon': '10d',
#               'id': 501,
#               'main': 'Rain'}],
#  'wind': {'deg': 120, 'gust': 24.16, 'speed': 16.11}}
# Processing Record 27 of Set 1 | victor harbor
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -35.5667, 'lon': 138.6167},
#  'dt': 1643330729,
#  'id': 2059470,
#  'main': {'feels_like': 73.27,
#           'humidity': 73,
#           'pressure': 1010,
#           'temp': 72.86,
#           'temp_max': 80.8,
#           'temp_min': 66.04},
#  'name': 'Victor Harbor',
#  'sys': {'country': 'AU',
#          'id': 2020876,
#          'sunrise': 1643313545,
#          'sunset': 1643363847,
#          'type': 2},
#  'timezone': 37800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 153, 'gust': 8.01, 'speed': 1.99}}
# Processing Record 28 of Set 1 | pevek
# {'base': 'stations',
#  'clouds': {'all': 27},
#  'cod': 200,
#  'coord': {'lat': 69.7008, 'lon': 170.3133},
#  'dt': 1643330731,
#  'id': 2122090,
#  'main': {'feels_like': -26.66,
#           'grnd_level': 1025,
#           'humidity': 99,
#           'pressure': 1032,
#           'sea_level': 1032,
#           'temp': -26.66,
#           'temp_max': -26.66,
#           'temp_min': -26.66},
#  'name': 'Pevek',
#  'sys': {'country': 'RU', 'sunrise': 1643323505, 'sunset': 1643338670},
#  'timezone': 43200,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 159, 'gust': 2.95, 'speed': 2.98}}
# Processing Record 29 of Set 1 | port alfred
# {'base': 'stations',
#  'clouds': {'all': 95},
#  'cod': 200,
#  'coord': {'lat': -33.5906, 'lon': 26.891},
#  'dt': 1643330733,
#  'id': 964432,
#  'main': {'feels_like': 71.91,
#           'grnd_level': 1008,
#           'humidity': 88,
#           'pressure': 1010,
#           'sea_level': 1010,
#           'temp': 70.97,
#           'temp_max': 70.97,
#           'temp_min': 70.97},
#  'name': 'Port Alfred',
#  'sys': {'country': 'ZA', 'sunrise': 1643340623, 'sunset': 1643390405},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 233, 'gust': 18.7, 'speed': 14.58}}
# Processing Record 30 of Set 1 | melo
# {'base': 'stations',
#  'clouds': {'all': 88},
#  'cod': 200,
#  'coord': {'lat': -32.3667, 'lon': -54.1833},
#  'dt': 1643330736,
#  'id': 3441702,
#  'main': {'feels_like': 63.01,
#           'grnd_level': 1006,
#           'humidity': 65,
#           'pressure': 1018,
#           'sea_level': 1018,
#           'temp': 63.88,
#           'temp_max': 63.88,
#           'temp_min': 63.88},
#  'name': 'Melo',
#  'sys': {'country': 'UY', 'sunrise': 1643273781, 'sunset': 1643323343},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 137, 'gust': 23.06, 'speed': 10.25}}
# Processing Record 31 of Set 1 | thompson
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 55.7435, 'lon': -97.8558},
#  'dt': 1643330534,
#  'id': 6165406,
#  'main': {'feels_like': -20.04,
#           'humidity': 71,
#           'pressure': 1021,
#           'temp': -7.44,
#           'temp_max': -7.44,
#           'temp_min': -7.44},
#  'name': 'Thompson',
#  'sys': {'country': 'CA',
#          'id': 935,
#          'sunrise': 1643294038,
#          'sunset': 1643324052,
#          'type': 1},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 260, 'speed': 5.75}}
# Processing Record 32 of Set 1 | bulungu
# {'base': 'stations',
#  'clouds': {'all': 27},
#  'cod': 200,
#  'coord': {'lat': -4.55, 'lon': 18.6},
#  'dt': 1643330741,
#  'id': 2316259,
#  'main': {'feels_like': 71.67,
#           'grnd_level': 960,
#           'humidity': 79,
#           'pressure': 1009,
#           'sea_level': 1009,
#           'temp': 71.15,
#           'temp_max': 71.15,
#           'temp_min': 71.15},
#  'name': 'Bulungu',
#  'sys': {'country': 'CD', 'sunrise': 1643345333, 'sunset': 1643389675},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 323, 'gust': 1.19, 'speed': 0.89}}
# Processing Record 33 of Set 1 | dickinson
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 29.4608, 'lon': -95.0513},
#  'dt': 1643330743,
#  'id': 4686163,
#  'main': {'feels_like': 52.72,
#           'humidity': 65,
#           'pressure': 1022,
#           'temp': 54.52,
#           'temp_max': 60.19,
#           'temp_min': 50.99},
#  'name': 'Dickinson',
#  'sys': {'country': 'US',
#          'id': 2004689,
#          'sunrise': 1643289126,
#          'sunset': 1643327617,
#          'type': 2},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 30, 'speed': 4.61}}
# Processing Record 34 of Set 1 | indiana
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 40.0003, 'lon': -86.2503},
#  'dt': 1643330745,
#  'id': 4921868,
#  'main': {'feels_like': 20.7,
#           'humidity': 82,
#           'pressure': 1022,
#           'temp': 28.62,
#           'temp_max': 30.65,
#           'temp_min': 26.26},
#  'name': 'Indiana',
#  'sys': {'country': 'US',
#          'id': 6096,
#          'sunrise': 1643288266,
#          'sunset': 1643324252,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 230, 'speed': 8.05}}
# Processing Record 35 of Set 1 | asau
# {'base': 'stations',
#  'clouds': {'all': 91},
#  'cod': 200,
#  'coord': {'lat': 46.4333, 'lon': 26.4},
#  'dt': 1643330748,
#  'id': 686090,
#  'main': {'feels_like': 28.18,
#           'grnd_level': 966,
#           'humidity': 89,
#           'pressure': 1017,
#           'sea_level': 1017,
#           'temp': 34.72,
#           'temp_max': 34.72,
#           'temp_min': 34.72},
#  'name': 'Asău',
#  'sys': {'country': 'RO',
#          'id': 6909,
#          'sunrise': 1643348570,
#          'sunset': 1643382693,
#          'type': 1},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 258, 'gust': 13.33, 'speed': 7.94}}
# Processing Record 36 of Set 1 | jomalig
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 37 of Set 1 | klaksvik
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 62.2266, 'lon': -6.589},
#  'dt': 1643330752,
#  'id': 2618795,
#  'main': {'feels_like': 33.06,
#           'grnd_level': 1016,
#           'humidity': 75,
#           'pressure': 1019,
#           'sea_level': 1019,
#           'temp': 41.92,
#           'temp_max': 41.92,
#           'temp_min': 41.92},
#  'name': 'Klaksvík',
#  'sys': {'country': 'FO',
#          'id': 1596,
#          'sunrise': 1643360656,
#          'sunset': 1643386444,
#          'type': 1},
#  'timezone': 0,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 249, 'gust': 24.67, 'speed': 19.75}}
# Processing Record 38 of Set 1 | castro
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -24.7911, 'lon': -50.0119},
#  'dt': 1643330755,
#  'id': 3466704,
#  'main': {'feels_like': 66.4,
#           'grnd_level': 901,
#           'humidity': 96,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 65.62,
#           'temp_max': 65.62,
#           'temp_min': 65.62},
#  'name': 'Castro',
#  'sys': {'country': 'BR', 'sunrise': 1643273601, 'sunset': 1643321520},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 102, 'gust': 5.91, 'speed': 3.15}}
# Processing Record 39 of Set 1 | bethel
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 41.3712, 'lon': -73.414},
#  'dt': 1643330757,
#  'id': 5282297,
#  'main': {'feels_like': 17.91,
#           'humidity': 74,
#           'pressure': 1023,
#           'temp': 22.53,
#           'temp_max': 29.64,
#           'temp_min': 16.84},
#  'name': 'Bethel',
#  'sys': {'country': 'US',
#          'id': 2004826,
#          'sunrise': 1643285379,
#          'sunset': 1643320977,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 230, 'speed': 3.44}}
# Processing Record 40 of Set 1 | dunedin
# {'base': 'stations',
#  'clouds': {'all': 15},
#  'cod': 200,
#  'coord': {'lat': -45.8742, 'lon': 170.5036},
#  'dt': 1643330638,
#  'id': 2191562,
#  'main': {'feels_like': 61.7,
#           'humidity': 62,
#           'pressure': 1025,
#           'temp': 62.8,
#           'temp_max': 62.8,
#           'temp_min': 62.8},
#  'name': 'Dunedin',
#  'sys': {'country': 'NZ',
#          'id': 75281,
#          'sunrise': 1643304326,
#          'sunset': 1643357758,
#          'type': 2},
#  'timezone': 46800,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 30, 'gust': 21, 'speed': 15.01}}
# Processing Record 41 of Set 1 | berlevag
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 70.8578, 'lon': 29.0864},
#  'dt': 1643330720,
#  'id': 780687,
#  'main': {'feels_like': 20.79,
#           'grnd_level': 995,
#           'humidity': 88,
#           'pressure': 996,
#           'sea_level': 996,
#           'temp': 27.05,
#           'temp_max': 27.05,
#           'temp_min': 27.05},
#  'name': 'Berlevåg',
#  'snow': {'1h': 0.12},
#  'sys': {'country': 'NO', 'sunrise': 1643358859, 'sunset': 1643371115},
#  'timezone': 3600,
#  'visibility': 3401,
#  'weather': [{'description': 'light snow',
#               'icon': '13n',
#               'id': 600,
#               'main': 'Snow'}],
#  'wind': {'deg': 262, 'gust': 6.85, 'speed': 5.5}}
# Processing Record 42 of Set 1 | hobart
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -42.8794, 'lon': 147.3294},
#  'dt': 1643330765,
#  'id': 2163355,
#  'main': {'feels_like': 84.15,
#           'humidity': 57,
#           'pressure': 1003,
#           'temp': 82.18,
#           'temp_max': 87.03,
#           'temp_min': 77.22},
#  'name': 'Hobart',
#  'sys': {'country': 'AU',
#          'id': 2002195,
#          'sunrise': 1643310406,
#          'sunset': 1643362803,
#          'type': 2},
#  'timezone': 39600,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 135, 'gust': 1.99, 'speed': 1.01}}
# Processing Record 43 of Set 1 | okhotsk
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 59.3833, 'lon': 143.3},
#  'dt': 1643330767,
#  'id': 2122605,
#  'main': {'feels_like': -14.64,
#           'grnd_level': 1006,
#           'humidity': 80,
#           'pressure': 1007,
#           'sea_level': 1007,
#           'temp': -2.04,
#           'temp_max': -2.04,
#           'temp_min': -2.04},
#  'name': 'Okhotsk',
#  'sys': {'country': 'RU', 'sunrise': 1643323641, 'sunset': 1643351502},
#  'timezone': 36000,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 337, 'gust': 26.31, 'speed': 18.7}}
# Processing Record 44 of Set 1 | chokurdakh
# {'base': 'stations',
#  'clouds': {'all': 57},
#  'cod': 200,
#  'coord': {'lat': 70.6333, 'lon': 147.9167},
#  'dt': 1643330503,
#  'id': 2126123,
#  'main': {'feels_like': -37.26,
#           'grnd_level': 1023,
#           'humidity': 91,
#           'pressure': 1027,
#           'sea_level': 1027,
#           'temp': -24.66,
#           'temp_max': -24.66,
#           'temp_min': -24.66},
#  'name': 'Chokurdakh',
#  'sys': {'country': 'RU', 'sunrise': 1643330128, 'sunset': 1643342799},
#  'timezone': 39600,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 197, 'gust': 17.85, 'speed': 9.57}}
# Processing Record 45 of Set 1 | cairns
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -16.9167, 'lon': 145.7667},
#  'dt': 1643330642,
#  'id': 2172797,
#  'main': {'feels_like': 99.61,
#           'humidity': 75,
#           'pressure': 1006,
#           'temp': 87.01,
#           'temp_max': 88.11,
#           'temp_min': 85.95},
#  'name': 'Cairns',
#  'sys': {'country': 'AU',
#          'id': 9490,
#          'sunrise': 1643313772,
#          'sunset': 1643360187,
#          'type': 1},
#  'timezone': 36000,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 270, 'speed': 1.14}}
# Processing Record 46 of Set 1 | albany
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 42.6001, 'lon': -73.9662},
#  'dt': 1643330733,
#  'id': 5106841,
#  'main': {'feels_like': 17.38,
#           'humidity': 54,
#           'pressure': 1018,
#           'temp': 22.51,
#           'temp_max': 24.46,
#           'temp_min': 17.15},
#  'name': 'Albany',
#  'sys': {'country': 'US',
#          'id': 19530,
#          'sunrise': 1643285691,
#          'sunset': 1643320930,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 191, 'gust': 8.05, 'speed': 3.8}}
# Processing Record 47 of Set 1 | atuona
# {'base': 'stations',
#  'clouds': {'all': 9},
#  'cod': 200,
#  'coord': {'lat': -9.8, 'lon': -139.0333},
#  'dt': 1643330777,
#  'id': 4020109,
#  'main': {'feels_like': 79.27,
#           'grnd_level': 1004,
#           'humidity': 75,
#           'pressure': 1012,
#           'sea_level': 1012,
#           'temp': 78.22,
#           'temp_max': 78.22,
#           'temp_min': 78.22},
#  'name': 'Atuona',
#  'sys': {'country': 'PF', 'sunrise': 1643296326, 'sunset': 1643341531},
#  'timezone': -34200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 86, 'gust': 17.72, 'speed': 17.38}}
# Processing Record 48 of Set 1 | sawakin
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 19.1059, 'lon': 37.3321},
#  'dt': 1643330779,
#  'id': 367544,
#  'main': {'feels_like': 65.79,
#           'grnd_level': 1017,
#           'humidity': 63,
#           'pressure': 1018,
#           'sea_level': 1018,
#           'temp': 66.47,
#           'temp_max': 66.47,
#           'temp_min': 66.47},
#  'name': 'Sawākin',
#  'sys': {'country': 'SD', 'sunrise': 1643342757, 'sunset': 1643383258},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 339, 'gust': 19.51, 'speed': 14.76}}
# Processing Record 49 of Set 1 | urusha
# {'base': 'stations',
#  'clouds': {'all': 76},
#  'cod': 200,
#  'coord': {'lat': 54.05, 'lon': 122.9},
#  'dt': 1643330782,
#  'id': 2014078,
#  'main': {'feels_like': -12.71,
#           'grnd_level': 961,
#           'humidity': 83,
#           'pressure': 1027,
#           'sea_level': 1027,
#           'temp': -3.41,
#           'temp_max': -3.41,
#           'temp_min': -3.41},
#  'name': 'Urusha',
#  'sys': {'country': 'RU', 'sunrise': 1643326980, 'sunset': 1643357956},
#  'timezone': 32400,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 307, 'gust': 7.63, 'speed': 3.94}}
# Processing Record 50 of Set 1 | talara
# {'base': 'stations',
#  'clouds': {'all': 86},
#  'cod': 200,
#  'coord': {'lat': -4.5772, 'lon': -81.2719},
#  'dt': 1643330784,
#  'id': 3691582,
#  'main': {'feels_like': 72.43,
#           'grnd_level': 1011,
#           'humidity': 86,
#           'pressure': 1013,
#           'sea_level': 1013,
#           'temp': 71.53,
#           'temp_max': 71.53,
#           'temp_min': 71.53},
#  'name': 'Talara',
#  'sys': {'country': 'PE', 'sunrise': 1643282887, 'sunset': 1643327241},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 198, 'gust': 9.19, 'speed': 7.72}}
# Processing Record 1 of Set 2 | qaanaaq
# {'base': 'stations',
#  'clouds': {'all': 31},
#  'cod': 200,
#  'coord': {'lat': 77.484, 'lon': -69.3632},
#  'dt': 1643330787,
#  'id': 3831208,
#  'main': {'feels_like': -22.63,
#           'grnd_level': 999,
#           'humidity': 71,
#           'pressure': 1003,
#           'sea_level': 1003,
#           'temp': -10.03,
#           'temp_max': -10.03,
#           'temp_min': -10.03},
#  'name': 'Qaanaaq',
#  'sys': {'country': 'GL', 'sunrise': 0, 'sunset': 0},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 32, 'gust': 7.34, 'speed': 7.56}}
# Processing Record 2 of Set 2 | port hardy
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 50.6996, 'lon': -127.4199},
#  'dt': 1643330734,
#  'id': 6111862,
#  'main': {'feels_like': 42.87,
#           'humidity': 57,
#           'pressure': 1023,
#           'temp': 48.38,
#           'temp_max': 48.38,
#           'temp_min': 48.38},
#  'name': 'Port Hardy',
#  'sys': {'country': 'CA',
#          'id': 1011,
#          'sunrise': 1643299928,
#          'sunset': 1643332355,
#          'type': 1},
#  'timezone': -28800,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 110, 'gust': 23.02, 'speed': 13.8}}
# Processing Record 3 of Set 2 | waipawa
# {'base': 'stations',
#  'clouds': {'all': 30},
#  'cod': 200,
#  'coord': {'lat': -41.4122, 'lon': 175.5153},
#  'dt': 1643330791,
#  'id': 2206874,
#  'main': {'feels_like': 59.34,
#           'grnd_level': 998,
#           'humidity': 48,
#           'pressure': 1028,
#           'sea_level': 1028,
#           'temp': 61.27,
#           'temp_max': 64.92,
#           'temp_min': 59.63},
#  'name': 'Waipawa',
#  'sys': {'country': 'NZ',
#          'id': 2017525,
#          'sunrise': 1643303866,
#          'sunset': 1643355811,
#          'type': 2},
#  'timezone': 46800,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 156, 'gust': 8.21, 'speed': 7.78}}
# Processing Record 4 of Set 2 | sentyabrskiy
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 5 of Set 2 | aksu
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 41.1231, 'lon': 80.2644},
#  'dt': 1643330796,
#  'id': 1529660,
#  'main': {'feels_like': 19.26,
#           'grnd_level': 896,
#           'humidity': 65,
#           'pressure': 1029,
#           'sea_level': 1029,
#           'temp': 19.26,
#           'temp_max': 19.26,
#           'temp_min': 19.26},
#  'name': 'Aksu',
#  'sys': {'country': 'CN', 'sunrise': 1643334832, 'sunset': 1643370573},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 148, 'gust': 2.57, 'speed': 2.06}}
# Processing Record 6 of Set 2 | iqaluit
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 63.7506, 'lon': -68.5145},
#  'dt': 1643330799,
#  'id': 5983720,
#  'main': {'feels_like': -9.31,
#           'humidity': 69,
#           'pressure': 994,
#           'temp': -9.31,
#           'temp_max': -9.31,
#           'temp_min': -9.67},
#  'name': 'Iqaluit',
#  'sys': {'country': 'CA',
#          'id': 47658,
#          'sunrise': 1643289966,
#          'sunset': 1643314037,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'light snow',
#               'icon': '13n',
#               'id': 600,
#               'main': 'Snow'}],
#  'wind': {'deg': 0, 'speed': 0}}
# Processing Record 7 of Set 2 | laguna
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 38.421, 'lon': -121.4238},
#  'dt': 1643330801,
#  'id': 5364271,
#  'main': {'feels_like': 58.59,
#           'humidity': 43,
#           'pressure': 1023,
#           'temp': 60.78,
#           'temp_max': 64.9,
#           'temp_min': 55.72},
#  'name': 'Laguna',
#  'sys': {'country': 'US',
#          'id': 5769,
#          'sunrise': 1643296493,
#          'sunset': 1643332911,
#          'type': 1},
#  'timezone': -28800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 0, 'speed': 0}}
# Processing Record 8 of Set 2 | vung tau
# {'base': 'stations',
#  'clouds': {'all': 17},
#  'cod': 200,
#  'coord': {'lat': 10.346, 'lon': 107.0843},
#  'dt': 1643330803,
#  'id': 1562414,
#  'main': {'feels_like': 77.54,
#           'grnd_level': 1011,
#           'humidity': 77,
#           'pressure': 1012,
#           'sea_level': 1012,
#           'temp': 76.57,
#           'temp_max': 76.57,
#           'temp_min': 76.57},
#  'name': 'Vung Tau',
#  'sys': {'country': 'VN', 'sunrise': 1643325281, 'sunset': 1643367248},
#  'timezone': 25200,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 327, 'gust': 7.87, 'speed': 6.93}}
# Processing Record 9 of Set 2 | lebu
# {'base': 'stations',
#  'clouds': {'all': 6},
#  'cod': 200,
#  'coord': {'lat': -37.6167, 'lon': -73.65},
#  'dt': 1643330806,
#  'id': 3883457,
#  'main': {'feels_like': 60.24,
#           'grnd_level': 1011,
#           'humidity': 94,
#           'pressure': 1015,
#           'sea_level': 1015,
#           'temp': 60.12,
#           'temp_max': 60.12,
#           'temp_min': 60.12},
#  'name': 'Lebu',
#  'sys': {'country': 'CL', 'sunrise': 1643277791, 'sunset': 1643328678},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 217, 'gust': 3.2, 'speed': 2.84}}
# Processing Record 10 of Set 2 | khatanga
# {'base': 'stations',
#  'clouds': {'all': 76},
#  'cod': 200,
#  'coord': {'lat': 71.9667, 'lon': 102.5},
#  'dt': 1643330808,
#  'id': 2022572,
#  'main': {'feels_like': -10.01,
#           'grnd_level': 1018,
#           'humidity': 79,
#           'pressure': 1022,
#           'sea_level': 1022,
#           'temp': 2.59,
#           'temp_max': 2.59,
#           'temp_min': 2.59},
#  'name': 'Khatanga',
#  'sys': {'country': 'RU', 'sunrise': 1643343744, 'sunset': 1643350986},
#  'timezone': 25200,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 233, 'gust': 31.79, 'speed': 14.47}}
# Processing Record 11 of Set 2 | karuzi
# {'base': 'stations',
#  'clouds': {'all': 96},
#  'cod': 200,
#  'coord': {'lat': -3.125, 'lon': 30.1333},
#  'dt': 1643330811,
#  'id': 428218,
#  'main': {'feels_like': 58.87,
#           'grnd_level': 846,
#           'humidity': 95,
#           'pressure': 1013,
#           'sea_level': 1013,
#           'temp': 58.82,
#           'temp_max': 58.82,
#           'temp_min': 58.82},
#  'name': 'Karuzi Province',
#  'sys': {'country': 'BI', 'sunrise': 1643342678, 'sunset': 1643386793},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 271, 'gust': 2.24, 'speed': 2.3}}
# Processing Record 12 of Set 2 | eureka
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 40.8021, 'lon': -124.1637},
#  'dt': 1643330813,
#  'id': 5563397,
#  'main': {'feels_like': 52.92,
#           'humidity': 69,
#           'pressure': 1022,
#           'temp': 54.52,
#           'temp_max': 56.19,
#           'temp_min': 51.19},
#  'name': 'Eureka',
#  'sys': {'country': 'US',
#          'id': 2019045,
#          'sunrise': 1643297471,
#          'sunset': 1643333248,
#          'type': 2},
#  'timezone': -28800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 311, 'gust': 3, 'speed': 3}}
# Processing Record 13 of Set 2 | barrow
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 71.2906, 'lon': -156.7887},
#  'dt': 1643330816,
#  'id': 5880054,
#  'main': {'feels_like': -29.18,
#           'humidity': 76,
#           'pressure': 1032,
#           'temp': -16.58,
#           'temp_max': -16.58,
#           'temp_min': -16.58},
#  'name': 'Barrow',
#  'sys': {'country': 'US',
#          'id': 7649,
#          'sunrise': 1643318096,
#          'sunset': 1643328286,
#          'type': 1},
#  'timezone': -32400,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 250, 'speed': 8.05}}
# Processing Record 14 of Set 2 | slonim
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 53.0867, 'lon': 25.3219},
#  'dt': 1643330818,
#  'id': 621754,
#  'main': {'feels_like': 23.47,
#           'grnd_level': 984,
#           'humidity': 97,
#           'pressure': 1001,
#           'sea_level': 1001,
#           'temp': 33.62,
#           'temp_max': 33.62,
#           'temp_min': 33.62},
#  'name': 'Slonim',
#  'snow': {'1h': 0.16},
#  'sys': {'country': 'BY', 'sunrise': 1643350144, 'sunset': 1643381636},
#  'timezone': 10800,
#  'visibility': 373,
#  'weather': [{'description': 'light snow',
#               'icon': '13n',
#               'id': 600,
#               'main': 'Snow'}],
#  'wind': {'deg': 244, 'gust': 32.59, 'speed': 15.59}}
# Processing Record 15 of Set 2 | fortuna
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 40.5982, 'lon': -124.1573},
#  'dt': 1643330669,
#  'id': 5563839,
#  'main': {'feels_like': 52.43,
#           'humidity': 75,
#           'pressure': 1023,
#           'temp': 53.82,
#           'temp_max': 57.18,
#           'temp_min': 50.92},
#  'name': 'Fortuna',
#  'sys': {'country': 'US',
#          'id': 2008778,
#          'sunrise': 1643297441,
#          'sunset': 1643333275,
#          'type': 2},
#  'timezone': -28800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 329, 'gust': 4, 'speed': 1.99}}
# Processing Record 16 of Set 2 | tabiauea
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 17 of Set 2 | isangel
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -19.55, 'lon': 169.2667},
#  'dt': 1643330535,
#  'id': 2136825,
#  'main': {'feels_like': 99.97,
#           'humidity': 70,
#           'pressure': 1007,
#           'temp': 87.91,
#           'temp_max': 87.91,
#           'temp_min': 87.91},
#  'name': 'Isangel',
#  'sys': {'country': 'VU',
#          'id': 7317,
#          'sunrise': 1643307892,
#          'sunset': 1643354785,
#          'type': 1},
#  'timezone': 39600,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 40, 'speed': 6.91}}
# Processing Record 18 of Set 2 | chapais
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 49.7834, 'lon': -74.8492},
#  'dt': 1643330827,
#  'id': 5919850,
#  'main': {'feels_like': -13.22,
#           'grnd_level': 963,
#           'humidity': 96,
#           'pressure': 1016,
#           'sea_level': 1016,
#           'temp': -0.62,
#           'temp_max': -0.62,
#           'temp_min': -0.62},
#  'name': 'Chapais',
#  'snow': {'1h': 0.18},
#  'sys': {'country': 'CA',
#          'id': 859,
#          'sunrise': 1643287136,
#          'sunset': 1643319909,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 253,
#  'weather': [{'description': 'light snow',
#               'icon': '13n',
#               'id': 600,
#               'main': 'Snow'}],
#  'wind': {'deg': 318, 'gust': 21.77, 'speed': 10.18}}
# Processing Record 19 of Set 2 | cabo san lucas
# {'base': 'stations',
#  'clouds': {'all': 31},
#  'cod': 200,
#  'coord': {'lat': 22.8909, 'lon': -109.9124},
#  'dt': 1643330829,
#  'id': 3985710,
#  'main': {'feels_like': 70.43,
#           'grnd_level': 1015,
#           'humidity': 55,
#           'pressure': 1016,
#           'sea_level': 1016,
#           'temp': 71.04,
#           'temp_max': 72.7,
#           'temp_min': 69.51},
#  'name': 'Cabo San Lucas',
#  'sys': {'country': 'MX',
#          'id': 2006274,
#          'sunrise': 1643292046,
#          'sunset': 1643331832,
#          'type': 2},
#  'timezone': -25200,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 325, 'gust': 5.79, 'speed': 2.21}}
# Processing Record 20 of Set 2 | jinka
# {'base': 'stations',
#  'clouds': {'all': 64},
#  'cod': 200,
#  'coord': {'lat': 5.65, 'lon': 36.65},
#  'dt': 1643330832,
#  'id': 333750,
#  'main': {'feels_like': 63.84,
#           'grnd_level': 858,
#           'humidity': 36,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 65.86,
#           'temp_max': 65.86,
#           'temp_min': 65.86},
#  'name': 'Jinka',
#  'sys': {'country': 'ET', 'sunrise': 1643341809, 'sunset': 1643384534},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 60, 'gust': 3.22, 'speed': 1.59}}
# Processing Record 21 of Set 2 | zlitan
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 32.4674, 'lon': 14.5687},
#  'dt': 1643330580,
#  'id': 2208485,
#  'main': {'feels_like': 49.71,
#           'grnd_level': 1028,
#           'humidity': 68,
#           'pressure': 1029,
#           'sea_level': 1029,
#           'temp': 51.66,
#           'temp_max': 51.66,
#           'temp_min': 51.66},
#  'name': 'Zliten',
#  'sys': {'country': 'LY', 'sunrise': 1643349519, 'sunset': 1643387424},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 272, 'gust': 8.93, 'speed': 8.77}}
# Processing Record 22 of Set 2 | katsuura
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 35.1333, 'lon': 140.3},
#  'dt': 1643330836,
#  'id': 2112309,
#  'main': {'feels_like': 41.16,
#           'grnd_level': 1017,
#           'humidity': 97,
#           'pressure': 1017,
#           'sea_level': 1017,
#           'temp': 45.91,
#           'temp_max': 47.19,
#           'temp_min': 41.04},
#  'name': 'Katsuura',
#  'sys': {'country': 'JP',
#          'id': 20334,
#          'sunrise': 1643319660,
#          'sunset': 1643356923,
#          'type': 2},
#  'timezone': 32400,
#  'visibility': 145,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 25, 'gust': 9.84, 'speed': 9.48}}
# Processing Record 23 of Set 2 | clyde river
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 70.4692, 'lon': -68.5914},
#  'dt': 1643330839,
#  'id': 5924351,
#  'main': {'feels_like': -19.97,
#           'humidity': 84,
#           'pressure': 1000,
#           'temp': -7.37,
#           'temp_max': -7.37,
#           'temp_min': -7.37},
#  'name': 'Clyde River',
#  'sys': {'country': 'CA',
#          'id': 776,
#          'sunrise': 1643295606,
#          'sunset': 1643308434,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 1609,
#  'weather': [{'description': 'light snow',
#               'icon': '13n',
#               'id': 600,
#               'main': 'Snow'}],
#  'wind': {'deg': 330, 'speed': 23.02}}
# Processing Record 24 of Set 2 | dingle
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 10.9995, 'lon': 122.6711},
#  'dt': 1643330841,
#  'id': 1714733,
#  'main': {'feels_like': 87.69,
#           'grnd_level': 1009,
#           'humidity': 81,
#           'pressure': 1012,
#           'sea_level': 1012,
#           'temp': 81.45,
#           'temp_max': 81.45,
#           'temp_min': 81.45},
#  'name': 'Dingle',
#  'sys': {'country': 'PH', 'sunrise': 1643321593, 'sunset': 1643363453},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 33, 'gust': 10.2, 'speed': 7.2}}
# Processing Record 25 of Set 2 | lingyuan
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 41.24, 'lon': 119.4011},
#  'dt': 1643330844,
#  'id': 2036075,
#  'main': {'feels_like': 14.72,
#           'grnd_level': 982,
#           'humidity': 41,
#           'pressure': 1033,
#           'sea_level': 1033,
#           'temp': 14.72,
#           'temp_max': 14.72,
#           'temp_min': 14.72},
#  'name': 'Lingyuan',
#  'sys': {'country': 'CN', 'sunrise': 1643325461, 'sunset': 1643361155},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 272, 'gust': 3.56, 'speed': 2.91}}
# Processing Record 26 of Set 2 | ilulissat
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 69.2167, 'lon': -51.1},
#  'dt': 1643330846,
#  'id': 3423146,
#  'main': {'feels_like': -5.78,
#           'humidity': 72,
#           'pressure': 1009,
#           'temp': 6.82,
#           'temp_max': 6.82,
#           'temp_min': 6.82},
#  'name': 'Ilulissat',
#  'sys': {'country': 'GL',
#          'id': 165,
#          'sunrise': 1643289812,
#          'sunset': 1643305832,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 140, 'speed': 10.36}}
# Processing Record 27 of Set 2 | mason city
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 43.1536, 'lon': -93.201},
#  'dt': 1643330849,
#  'id': 4866445,
#  'main': {'feels_like': 1.27,
#           'humidity': 76,
#           'pressure': 1025,
#           'temp': 13.87,
#           'temp_max': 19.78,
#           'temp_min': 12.29},
#  'name': 'Mason City',
#  'sys': {'country': 'US',
#          'id': 4856,
#          'sunrise': 1643290387,
#          'sunset': 1643325468,
#          'type': 1},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 320, 'speed': 19.57}}
# Processing Record 28 of Set 2 | illoqqortoormiut
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 29 of Set 2 | puerto ayora
# {'base': 'stations',
#  'clouds': {'all': 53},
#  'cod': 200,
#  'coord': {'lat': -0.7393, 'lon': -90.3518},
#  'dt': 1643330853,
#  'id': 3652764,
#  'main': {'feels_like': 74.82,
#           'grnd_level': 1006,
#           'humidity': 84,
#           'pressure': 1012,
#           'sea_level': 1012,
#           'temp': 73.8,
#           'temp_max': 73.8,
#           'temp_min': 73.8},
#  'name': 'Puerto Ayora',
#  'sys': {'country': 'EC', 'sunrise': 1643285375, 'sunset': 1643329113},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 182, 'gust': 10.45, 'speed': 6.89}}
# Processing Record 30 of Set 2 | tasiilaq
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 65.6145, 'lon': -37.6368},
#  'dt': 1643330856,
#  'id': 3424607,
#  'main': {'feels_like': 11.89,
#           'grnd_level': 990,
#           'humidity': 95,
#           'pressure': 995,
#           'sea_level': 995,
#           'temp': 21.36,
#           'temp_max': 21.36,
#           'temp_min': 21.36},
#  'name': 'Tasiilaq',
#  'snow': {'1h': 0.29},
#  'sys': {'country': 'GL',
#          'id': 81,
#          'sunrise': 1643283626,
#          'sunset': 1643305554,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 178,
#  'weather': [{'description': 'light snow',
#               'icon': '13n',
#               'id': 600,
#               'main': 'Snow'}],
#  'wind': {'deg': 230, 'gust': 11.88, 'speed': 7.99}}
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24968\2183011133.py in <module>
#      56 print("-----------------------------")
#      57 print("Data Retrieval Complete      ")
# ---> 58 print("-----------------------------") (edited)
#
# NameError: name 'edited' is not defined

# %%
len(city_data)
# Out:
# 74

# %%
# convert to data frame
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#             City      Lat       Lng  Max Temp Current Description  \
# 0      Hithadhoo  -0.6000   73.0833     81.00     overcast clouds
# 1        Ushtobe  45.2514   77.9838     14.11          few clouds
# 2     Butaritari   3.0707  172.7902     82.31           clear sky
# 3       Hargeysa   9.5600   44.0650     54.32    scattered clouds
# 4          Vaini -21.2000 -175.2000     82.83          few clouds
# ..           ...      ...       ...       ...                 ...
# 69      Lingyuan  41.2400  119.4011     14.72           clear sky
# 70     Ilulissat  69.2167  -51.1000      6.82          few clouds
# 71    Mason City  43.1536  -93.2010     19.78           clear sky
# 72  Puerto Ayora  -0.7393  -90.3518     73.80       broken clouds
# 73      Tasiilaq  65.6145  -37.6368     21.36          light snow
#
#     Rain (inches)  Snow (inches)  Humidity  Cloudiness  Wind Speed Country
# 0             0.0           0.00        70         100       14.54      MV
# 1             0.0           0.00        88          20       10.07      KZ
# 2             0.0           0.00        77           2       15.68      KI
# 3             0.0           0.00        57          35       12.33      SO
# 4             0.0           0.00        78          21       14.56      TO
# ..            ...            ...       ...         ...         ...     ...
# 69            0.0           0.00        41           0        2.91      CN
# 70            0.0           0.00        72          20       10.36      GL
# 71            0.0           0.00        76           0       19.57      US
# 72            0.0           0.00        84          53        6.89      EC
# 73            0.0           0.29        95         100        7.99      GL
#
# [74 rows x 11 columns]

# %%
# Create the output File (CSV)
output_data_file = "Resources/WeatherPy_Database.csv"

# Export the city_data into a csv
city_data_df.to_csv(output_data_file, index_label="City_ID")
